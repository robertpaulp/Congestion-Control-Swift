# %% [markdown]
# # Proiect Congestion Control
#
# Vom folosi acest notebook pentru vizualizarea comportamentului algoritmului implementat. Pentru realizarea graficelor aferent este folosita biblioteca `matplotlib`. In Jupyter comenzile precedate de `!` sunt rulate din bash. Punctajul acordat este calculat pe trei categorii: throughput, latency si fariness.
#
# > Vom considera MSS = 1500 bytes

# %% [markdown]
# ### Inainte de a rula simulatorul
#
# Vom folosi matplotlib pentru a realiza graficele. Rezultatele rularii simulatorului se vor gasi in directorul `tmp`.

# %%
pip install matplotlib

# %%
# Note: comenzile prefixate cu ! sunt rulate in Bash, nu in Python!
# !mkdir -p tmp/t

# %%
# O sa intalnim des apelul functiei format pe un string. Aceasta este similara cu %s sau %d in printf.

string = "ceva{}".format(4)
print(string)

# %% [markdown]
# ### Cod pentru desenarea graficelor

# %%
import matplotlib.pyplot as plt

# Fiecare fisier .dat dim tmp contine date despre o conexiune. Acestea au urmatorul format:
# 0.100000000 Type CC_SINK ID 0 Ev RATE CAck 3643500 CWND 1776791 Rate 36435000
# De exemplu la indexul 0 se afla timestamp-ul, iar la indexul 12 throughput-ul

def plot_generic(axs, index_f1, index_f2, ylabel, xlabel, scale_y, num_cons, data_folder="tmp/t/"):
    for i in range(num_cons):
        x1, y1 = [], []
        # Citeste throughput-ul din fisierul aferent conexiunii i
        with open("{}{}.dat".format(data_folder, i)) as f:
            for line in f:
                values = line.split()
                x1.append(float(values[index_f1]))
                y1.append(float(values[index_f2]) * scale_y)
        axs.plot(x1, y1, '-', label='Conn {}'.format(i))
        axs.legend()
    
def plot_throughput(axs, num_cons):
    axs.set_ylabel('Throughput (Mbps)')
    axs.set_xlabel('Time (s)')
    # Valorile din fisieri sunt in byes asa ca le inmultim cu 8/1000000 ca sa trecem in Mb/s
    plot_generic(axs, 0, 12, 'Throughput', 'Time (s)', 8 / 1000000, num_cons)

def plot_cwnd(axs, num_cons):
    axs.set_ylabel('CWND (MSS)')
    axs.set_xlabel('Time (s)')
    plot_generic(axs, 0, 10, 'CWND (MSS)', 'Time (s)', 1/1500, num_cons)

def plot_router_queue(axs, max_queue_size, data_folder="tmp/t/"):
    axs.set_ylabel('Packets in Queue (MSS) ')
    axs.set_xlabel('Time (s)')
    x1, y1 = [], []
    with open("{}q.dat".format(data_folder)) as f:
        for line in f:
            values = line.split()
            x1.append(float(values[0]))
            y1.append(float(values[12]) * 1/1500)
        
        axs.hlines(y=max_queue_size, xmin=0, xmax=x1[-1], linewidth=2, color='r')
        axs.plot(x1, y1, '-')

# %% [markdown]
# ### Masurarea performantei algoritmului de congestion control
#
# Urmatoarele celule compileaza si ruleaza simulatorul. Ulterior vom folosii functile definite in sectiunile precedente pentru a realiza graficele valorilor CWND, viteza de transmisie, fairness, coada de pachete din router etc. Acestea ne vor ajuta in a intelege performanta protocolului nostru.

# %%
# Inainte de a rula o simulare, vom chema make
# !make -s

# Rulam simulatorul (vezi main_dumbell_cc.cpp)
# -cons numarul de conexiuni
# -end (ms) timpul de rulare al experimentului
# -latency (ms) latenta link-urilor
# -q dimensiunea cozii in MSS
# -startdelta (ms) de la ce timp sa porneasca o noua conexiune
# -log (ms) intervalul la care se fac masuratori pentrum cwnd
# -bandwidth (mbps) seteaza bandwidth-ul linkurilor
num_cons = 3
router_queue_size = 800
# Rulam simulatorul din bash. ./scripts/parse.sh logout.dat parseaza rezultatele si le scrie in format human readable in folder-ul 
! ./htsim_dumbell_cc -conns {num_cons} -end 20000 -log 100 -q {router_queue_size} -latency 5 -startdelta 5000; ./scripts/parse.sh logout.dat tmp/t/
# Out:
# Rtt-ul este: 12083248000si nr ack-ului: 960498001
# Rtt-ul este: 12083248000si nr ack-ului: 960499501
# Rtt-ul este: 12095760000si nr ack-ului: 960501001
# Rtt-ul este: 12095760000si nr ack-ului: 960502501
# Rtt-ul este: 12108272000si nr ack-ului: 960504001
# Rtt-ul este: 12108272000si nr ack-ului: 960505501
# Rtt-ul este: 12120784000si nr ack-ului: 960507001
# Rtt-ul este: 12120784000si nr ack-ului: 960508501
# Rtt-ul este: 12133296000si nr ack-ului: 960510001
# Rtt-ul este: 12133296000si nr ack-ului: 960511501
# Rtt-ul este: 12145808000si nr ack-ului: 960513001
# Rtt-ul este: 12145808000si nr ack-ului: 960514501
# Rtt-ul este: 12158320000si nr ack-ului: 960516001
# Rtt-ul este: 12158320000si nr ack-ului: 960517501
# Rtt-ul este: 12170832000si nr ack-ului: 960519001
# Rtt-ul este: 12170832000si nr ack-ului: 960520501
# Rtt-ul este: 12183344000si nr ack-ului: 960522001
# Rtt-ul este: 12183344000si nr ack-ului: 960523501
# Rtt-ul este: 12195856000si nr ack-ului: 960525001
# Rtt-ul este: 12195856000si nr ack-ului: 960526501
# Rtt-ul este: 12208368000si nr ack-ului: 960528001
# Rtt-ul este: 12208368000si nr ack-ului: 960529501
# Rtt-ul este: 12220880000si nr ack-ului: 960531001
# Rtt-ul este: 12220880000si nr ack-ului: 960532501
# Rtt-ul este: 12233392000si nr ack-ului: 960534001
# Rtt-ul este: 12233392000si nr ack-ului: 960535501
# Rtt-ul este: 12245904000si nr ack-ului: 960537001
# Rtt-ul este: 12245904000si nr ack-ului: 960538501
# Rtt-ul este: 12258416000si nr ack-ului: 960540001
# Rtt-ul este: 12258416000si nr ack-ului: 960541501
# Rtt-ul este: 12270928000si nr ack-ului: 960543001
# Rtt-ul este: 12270928000si nr ack-ului: 960544501
# Rtt-ul este: 12283440000si nr ack-ului: 960546001
# Rtt-ul este: 12283440000si nr ack-ului: 960547501
# Rtt-ul este: 12295952000si nr ack-ului: 960549001
# Rtt-ul este: 12295952000si nr ack-ului: 960550501
# Rtt-ul este: 12308464000si nr ack-ului: 960552001
# Rtt-ul este: 12308464000si nr ack-ului: 960553501
# Rtt-ul este: 12320976000si nr ack-ului: 960555001
# Rtt-ul este: 12320976000si nr ack-ului: 960556501
# Rtt-ul este: 12333488000si nr ack-ului: 960558001
# Rtt-ul este: 12333488000si nr ack-ului: 960559501
# Rtt-ul este: 12346000000si nr ack-ului: 960561001
# Rtt-ul este: 12346000000si nr ack-ului: 960562501
# Rtt-ul este: 12358512000si nr ack-ului: 960564001
# Rtt-ul este: 12358512000si nr ack-ului: 960565501
# Rtt-ul este: 12371024000si nr ack-ului: 960567001
# Rtt-ul este: 12371024000si nr ack-ului: 960568501
# Rtt-ul este: 12383536000si nr ack-ului: 960570001
# Rtt-ul este: 12383536000si nr ack-ului: 960571501
# Rtt-ul este: 12396048000si nr ack-ului: 960573001
# Rtt-ul este: 12396048000si nr ack-ului: 960574501
# Rtt-ul este: 12408560000si nr ack-ului: 960576001
# Rtt-ul este: 12408560000si nr ack-ului: 960577501
# Rtt-ul este: 12421072000si nr ack-ului: 960579001
# Rtt-ul este: 12421072000si nr ack-ului: 960580501
# Rtt-ul este: 12433584000si nr ack-ului: 960582001
# Rtt-ul este: 12433584000si nr ack-ului: 960583501
# Rtt-ul este: 12446096000si nr ack-ului: 960585001
# Rtt-ul este: 12446096000si nr ack-ului: 960586501
# Rtt-ul este: 12458608000si nr ack-ului: 960588001
# Rtt-ul este: 12458608000si nr ack-ului: 960589501
# Rtt-ul este: 12471120000si nr ack-ului: 960591001
# Rtt-ul este: 12471120000si nr ack-ului: 960592501
# Rtt-ul este: 12483632000si nr ack-ului: 960594001
# Rtt-ul este: 12483632000si nr ack-ului: 960595501
# Rtt-ul este: 12496144000si nr ack-ului: 960597001
# Rtt-ul este: 12496144000si nr ack-ului: 960598501
# Rtt-ul este: 12508656000si nr ack-ului: 960600001
# Rtt-ul este: 12508656000si nr ack-ului: 960601501
# Rtt-ul este: 12521168000si nr ack-ului: 960603001
# Rtt-ul este: 12521168000si nr ack-ului: 960604501
# Rtt-ul este: 12533680000si nr ack-ului: 960606001
# Rtt-ul este: 12533680000si nr ack-ului: 960607501
# Rtt-ul este: 12546192000si nr ack-ului: 960609001
# Rtt-ul este: 12546192000si nr ack-ului: 960610501
# Rtt-ul este: 12558704000si nr ack-ului: 960612001
# Rtt-ul este: 12558704000si nr ack-ului: 960613501
# Rtt-ul este: 12571216000si nr ack-ului: 960615001
# Rtt-ul este: 12571216000si nr ack-ului: 960616501
# Rtt-ul este: 12583728000si nr ack-ului: 960618001
# Rtt-ul este: 12583728000si nr ack-ului: 960619501
# Rtt-ul este: 12596240000si nr ack-ului: 960621001
# Rtt-ul este: 12596240000si nr ack-ului: 960622501
# Rtt-ul este: 12608752000si nr ack-ului: 960624001
# Rtt-ul este: 12608752000si nr ack-ului: 960625501
# Rtt-ul este: 12621264000si nr ack-ului: 960627001
# Rtt-ul este: 12621264000si nr ack-ului: 960628501
# Rtt-ul este: 12633776000si nr ack-ului: 960630001
# Rtt-ul este: 12633776000si nr ack-ului: 960631501
# Rtt-ul este: 12646288000si nr ack-ului: 960633001
# Rtt-ul este: 12646288000si nr ack-ului: 960634501
# Rtt-ul este: 12658800000si nr ack-ului: 960636001
# Rtt-ul este: 12658800000si nr ack-ului: 960637501
# Rtt-ul este: 12671312000si nr ack-ului: 960639001
# Rtt-ul este: 12671312000si nr ack-ului: 960640501
# Rtt-ul este: 12683824000si nr ack-ului: 960642001
# Rtt-ul este: 12683824000si nr ack-ului: 960643501
# Rtt-ul este: 12696336000si nr ack-ului: 960645001
# Rtt-ul este: 12696336000si nr ack-ului: 960646501
# Rtt-ul este: 12708848000si nr ack-ului: 960648001
# Rtt-ul este: 12708848000si nr ack-ului: 960649501
# Rtt-ul este: 12721360000si nr ack-ului: 960651001
# Rtt-ul este: 12721360000si nr ack-ului: 960652501
# Rtt-ul este: 12733872000si nr ack-ului: 960654001
# Rtt-ul este: 12733872000si nr ack-ului: 960655501
# Rtt-ul este: 12746384000si nr ack-ului: 960657001
# Rtt-ul este: 12746384000si nr ack-ului: 960658501
# Rtt-ul este: 12758896000si nr ack-ului: 960660001
# Rtt-ul este: 12758896000si nr ack-ului: 960661501
# Rtt-ul este: 12771408000si nr ack-ului: 960663001
# Rtt-ul este: 12771408000si nr ack-ului: 960664501
# Rtt-ul este: 12783920000si nr ack-ului: 960666001
# Rtt-ul este: 12783920000si nr ack-ului: 960667501
# Rtt-ul este: 12796432000si nr ack-ului: 960669001
# Rtt-ul este: 12796432000si nr ack-ului: 960670501
# Rtt-ul este: 12808944000si nr ack-ului: 960672001
# Rtt-ul este: 12808944000si nr ack-ului: 960673501
# Rtt-ul este: 12821456000si nr ack-ului: 960675001
# Rtt-ul este: 12821456000si nr ack-ului: 960676501
# Rtt-ul este: 12833968000si nr ack-ului: 960678001
# Rtt-ul este: 12833968000si nr ack-ului: 960679501
# Rtt-ul este: 12846480000si nr ack-ului: 960681001
# Rtt-ul este: 12846480000si nr ack-ului: 960682501
# Rtt-ul este: 12858992000si nr ack-ului: 960684001
# Rtt-ul este: 12858992000si nr ack-ului: 960685501
# Rtt-ul este: 12871504000si nr ack-ului: 960687001
# Rtt-ul este: 12871504000si nr ack-ului: 960688501
# Rtt-ul este: 12884016000si nr ack-ului: 960690001
# Rtt-ul este: 12884016000si nr ack-ului: 960691501
# Rtt-ul este: 12896528000si nr ack-ului: 960693001
# Rtt-ul este: 12896528000si nr ack-ului: 960694501
# Rtt-ul este: 12909040000si nr ack-ului: 960696001
# Rtt-ul este: 12909040000si nr ack-ului: 960697501
# Rtt-ul este: 12921552000si nr ack-ului: 960699001
# Rtt-ul este: 12921552000si nr ack-ului: 960700501
# Rtt-ul este: 12934064000si nr ack-ului: 960702001
# Rtt-ul este: 12934064000si nr ack-ului: 960703501
# Rtt-ul este: 12946576000si nr ack-ului: 960705001
# Rtt-ul este: 12946576000si nr ack-ului: 960706501
# Rtt-ul este: 12959088000si nr ack-ului: 960708001
# Rtt-ul este: 12959088000si nr ack-ului: 960709501
# Rtt-ul este: 12971600000si nr ack-ului: 960711001
# Rtt-ul este: 12971600000si nr ack-ului: 960712501
# Rtt-ul este: 12984112000si nr ack-ului: 960714001
# Rtt-ul este: 12984112000si nr ack-ului: 960715501
# Rtt-ul este: 12996624000si nr ack-ului: 960717001
# Rtt-ul este: 12996624000si nr ack-ului: 960718501
# Rtt-ul este: 13009136000si nr ack-ului: 960720001
# Rtt-ul este: 13009136000si nr ack-ului: 960721501
# Rtt-ul este: 13021648000si nr ack-ului: 960723001
# Rtt-ul este: 13021648000si nr ack-ului: 960724501
# Rtt-ul este: 13034160000si nr ack-ului: 960726001
# Rtt-ul este: 13034160000si nr ack-ului: 960727501
# Rtt-ul este: 13046672000si nr ack-ului: 960729001
# Rtt-ul este: 13046672000si nr ack-ului: 960730501
# Rtt-ul este: 13059184000si nr ack-ului: 960732001
# Rtt-ul este: 13059184000si nr ack-ului: 960733501
# Rtt-ul este: 13071696000si nr ack-ului: 960735001
# Rtt-ul este: 13071696000si nr ack-ului: 960736501
# Rtt-ul este: 13084208000si nr ack-ului: 960738001
# Rtt-ul este: 13084208000si nr ack-ului: 960739501
# Rtt-ul este: 13096720000si nr ack-ului: 960741001
# Rtt-ul este: 13096720000si nr ack-ului: 960742501
# Rtt-ul este: 13109232000si nr ack-ului: 960744001
# Rtt-ul este: 13109232000si nr ack-ului: 960745501
# Rtt-ul este: 13121744000si nr ack-ului: 960747001
# Rtt-ul este: 13121744000si nr ack-ului: 960748501
# Rtt-ul este: 13134256000si nr ack-ului: 960750001
# Rtt-ul este: 13134256000si nr ack-ului: 960751501
# Rtt-ul este: 13146768000si nr ack-ului: 960753001
# Rtt-ul este: 13146768000si nr ack-ului: 960754501
# Rtt-ul este: 13159280000si nr ack-ului: 960756001
# Rtt-ul este: 13159280000si nr ack-ului: 960757501
# Rtt-ul este: 13171792000si nr ack-ului: 960759001
# Rtt-ul este: 13171792000si nr ack-ului: 960760501
# Rtt-ul este: 13184304000si nr ack-ului: 960762001
# Rtt-ul este: 13184304000si nr ack-ului: 960763501
# Rtt-ul este: 13196816000si nr ack-ului: 960765001
# Rtt-ul este: 13196816000si nr ack-ului: 960766501
# Rtt-ul este: 13209328000si nr ack-ului: 960768001
# Rtt-ul este: 13209328000si nr ack-ului: 960769501
# Rtt-ul este: 13221840000si nr ack-ului: 960771001
# Rtt-ul este: 13221840000si nr ack-ului: 960772501
# Rtt-ul este: 13234352000si nr ack-ului: 960774001
# Rtt-ul este: 13234352000si nr ack-ului: 960775501
# Rtt-ul este: 13246864000si nr ack-ului: 960777001
# Rtt-ul este: 13246864000si nr ack-ului: 960778501
# Rtt-ul este: 13259376000si nr ack-ului: 960780001
# Rtt-ul este: 13259376000si nr ack-ului: 960781501
# Rtt-ul este: 13271888000si nr ack-ului: 960783001
# Rtt-ul este: 13271888000si nr ack-ului: 960784501
# Rtt-ul este: 13284400000si nr ack-ului: 960786001
# Rtt-ul este: 13284400000si nr ack-ului: 960787501
# Rtt-ul este: 13296912000si nr ack-ului: 960789001
# Rtt-ul este: 13296912000si nr ack-ului: 960790501
# Rtt-ul este: 13309424000si nr ack-ului: 960792001
# Rtt-ul este: 13309424000si nr ack-ului: 960793501
# Rtt-ul este: 13321936000si nr ack-ului: 960795001
# Rtt-ul este: 13321936000si nr ack-ului: 960796501
# Rtt-ul este: 13334448000si nr ack-ului: 960798001
# Rtt-ul este: 13334448000si nr ack-ului: 960799501
# Rtt-ul este: 13346960000si nr ack-ului: 960801001
# Rtt-ul este: 13346960000si nr ack-ului: 960802501
# Rtt-ul este: 13359472000si nr ack-ului: 960804001
# Rtt-ul este: 13359472000si nr ack-ului: 960805501
# Rtt-ul este: 13371984000si nr ack-ului: 960807001
# Rtt-ul este: 13371984000si nr ack-ului: 960808501
# Rtt-ul este: 13384496000si nr ack-ului: 960810001
# Rtt-ul este: 13384496000si nr ack-ului: 960811501
# Rtt-ul este: 13397008000si nr ack-ului: 960813001
# Rtt-ul este: 13397008000si nr ack-ului: 960814501
# Rtt-ul este: 13409520000si nr ack-ului: 960816001
# Rtt-ul este: 13409520000si nr ack-ului: 960817501
# Rtt-ul este: 13422032000si nr ack-ului: 960819001
# Rtt-ul este: 13422032000si nr ack-ului: 960820501
# Rtt-ul este: 13434544000si nr ack-ului: 960822001
# Rtt-ul este: 13434544000si nr ack-ului: 960823501
# Rtt-ul este: 13447056000si nr ack-ului: 960825001
# Rtt-ul este: 13447056000si nr ack-ului: 960826501
# Rtt-ul este: 13459568000si nr ack-ului: 960828001
# Rtt-ul este: 13459568000si nr ack-ului: 960829501
# Rtt-ul este: 13472080000si nr ack-ului: 960831001
# Rtt-ul este: 13472080000si nr ack-ului: 960832501
# Rtt-ul este: 13484592000si nr ack-ului: 960834001
# Rtt-ul este: 13484592000si nr ack-ului: 960835501
# Rtt-ul este: 13497104000si nr ack-ului: 960837001
# Rtt-ul este: 13497104000si nr ack-ului: 960838501
# Rtt-ul este: 13509616000si nr ack-ului: 960840001
# Rtt-ul este: 13509616000si nr ack-ului: 960841501
# Rtt-ul este: 13522128000si nr ack-ului: 960843001
# Rtt-ul este: 13522128000si nr ack-ului: 960844501
# Rtt-ul este: 13534640000si nr ack-ului: 960846001
# Rtt-ul este: 13534640000si nr ack-ului: 960847501
# Rtt-ul este: 13547152000si nr ack-ului: 960849001
# Rtt-ul este: 13547152000si nr ack-ului: 960850501
# Rtt-ul este: 13559664000si nr ack-ului: 960852001
# Rtt-ul este: 13559664000si nr ack-ului: 960853501
# Rtt-ul este: 13572176000si nr ack-ului: 960855001
# Rtt-ul este: 13572176000si nr ack-ului: 960856501
# Rtt-ul este: 13584688000si nr ack-ului: 960858001
# Rtt-ul este: 13584688000si nr ack-ului: 960859501
# Rtt-ul este: 13597200000si nr ack-ului: 960861001
# Rtt-ul este: 13597200000si nr ack-ului: 960862501
# Rtt-ul este: 13609712000si nr ack-ului: 960864001
# Rtt-ul este: 13609712000si nr ack-ului: 960865501
# Rtt-ul este: 13622224000si nr ack-ului: 960867001
# Rtt-ul este: 13622224000si nr ack-ului: 960868501
# Rtt-ul este: 13634736000si nr ack-ului: 960870001
# Rtt-ul este: 13634736000si nr ack-ului: 960871501
# Rtt-ul este: 13647248000si nr ack-ului: 960873001
# Rtt-ul este: 13647248000si nr ack-ului: 960874501
# Rtt-ul este: 13659760000si nr ack-ului: 960876001
# Rtt-ul este: 13659760000si nr ack-ului: 960877501
# Rtt-ul este: 13672272000si nr ack-ului: 960879001
# Rtt-ul este: 13672272000si nr ack-ului: 960880501
# Rtt-ul este: 13684784000si nr ack-ului: 960882001
# Rtt-ul este: 13684784000si nr ack-ului: 960883501
# Rtt-ul este: 13697296000si nr ack-ului: 960885001
# Rtt-ul este: 13697296000si nr ack-ului: 960886501
# Rtt-ul este: 13709808000si nr ack-ului: 960888001
# Rtt-ul este: 13709808000si nr ack-ului: 960889501
# Rtt-ul este: 13722320000si nr ack-ului: 960891001
# Rtt-ul este: 13722320000si nr ack-ului: 960892501
# Rtt-ul este: 13734832000si nr ack-ului: 960894001
# Rtt-ul este: 13734832000si nr ack-ului: 960895501
# Rtt-ul este: 13747344000si nr ack-ului: 960897001
# Rtt-ul este: 13747344000si nr ack-ului: 960898501
# Rtt-ul este: 13759856000si nr ack-ului: 960900001
# Rtt-ul este: 13759856000si nr ack-ului: 960901501
# Rtt-ul este: 13772368000si nr ack-ului: 960903001
# Rtt-ul este: 13772368000si nr ack-ului: 960904501
# Rtt-ul este: 13784880000si nr ack-ului: 960906001
# Rtt-ul este: 13784880000si nr ack-ului: 960907501
# Rtt-ul este: 13797392000si nr ack-ului: 960909001
# Rtt-ul este: 13797392000si nr ack-ului: 960910501
# Rtt-ul este: 13809904000si nr ack-ului: 960912001
# Rtt-ul este: 13809904000si nr ack-ului: 960913501
# Rtt-ul este: 13822416000si nr ack-ului: 960915001
# Rtt-ul este: 13822416000si nr ack-ului: 960916501
# Rtt-ul este: 13834928000si nr ack-ului: 960918001
# Rtt-ul este: 13834928000si nr ack-ului: 960919501
# Rtt-ul este: 13847440000si nr ack-ului: 960921001
# Rtt-ul este: 13847440000si nr ack-ului: 960922501
# Rtt-ul este: 13859952000si nr ack-ului: 960924001
# Rtt-ul este: 13859952000si nr ack-ului: 960925501
# Rtt-ul este: 13872464000si nr ack-ului: 960927001
# Rtt-ul este: 13872464000si nr ack-ului: 960928501
# Rtt-ul este: 13884976000si nr ack-ului: 960930001
# Rtt-ul este: 13884976000si nr ack-ului: 960931501
# Rtt-ul este: 13897488000si nr ack-ului: 960933001
# Rtt-ul este: 13897488000si nr ack-ului: 960934501
# Rtt-ul este: 13910000000si nr ack-ului: 960936001
# Rtt-ul este: 13910000000si nr ack-ului: 960937501
# Rtt-ul este: 13922512000si nr ack-ului: 960939001
# Rtt-ul este: 13922512000si nr ack-ului: 960940501
# Rtt-ul este: 13935024000si nr ack-ului: 960942001
# Rtt-ul este: 13935024000si nr ack-ului: 960943501
# Rtt-ul este: 13947536000si nr ack-ului: 960945001
# Rtt-ul este: 13947536000si nr ack-ului: 960946501
# Rtt-ul este: 13960048000si nr ack-ului: 960948001
# Rtt-ul este: 13960048000si nr ack-ului: 960949501
# Rtt-ul este: 13972560000si nr ack-ului: 960951001
# Rtt-ul este: 13972560000si nr ack-ului: 960952501
# Rtt-ul este: 13985072000si nr ack-ului: 960954001
# Rtt-ul este: 13985072000si nr ack-ului: 960955501
# Rtt-ul este: 13997584000si nr ack-ului: 960957001
# Rtt-ul este: 13997584000si nr ack-ului: 960958501
# Rtt-ul este: 14010096000si nr ack-ului: 960960001
# Rtt-ul este: 14010096000si nr ack-ului: 960961501
# Rtt-ul este: 14022608000si nr ack-ului: 960963001
# Rtt-ul este: 14022608000si nr ack-ului: 960964501
# Rtt-ul este: 14035120000si nr ack-ului: 960966001
# Rtt-ul este: 14035120000si nr ack-ului: 960967501
# Rtt-ul este: 14047632000si nr ack-ului: 960969001
# Rtt-ul este: 14047632000si nr ack-ului: 960970501
# Rtt-ul este: 14060144000si nr ack-ului: 960972001
# Rtt-ul este: 14060144000si nr ack-ului: 960973501
# Rtt-ul este: 14072656000si nr ack-ului: 960975001
# Rtt-ul este: 14072656000si nr ack-ului: 960976501
# Rtt-ul este: 14085168000si nr ack-ului: 960978001
# Rtt-ul este: 14085168000si nr ack-ului: 960979501
# Rtt-ul este: 14097680000si nr ack-ului: 960981001
# Rtt-ul este: 14097680000si nr ack-ului: 960982501
# Rtt-ul este: 14110192000si nr ack-ului: 960984001
# Rtt-ul este: 14110192000si nr ack-ului: 960985501
# Rtt-ul este: 14122704000si nr ack-ului: 960987001
# Rtt-ul este: 14122704000si nr ack-ului: 960988501
# Rtt-ul este: 14135216000si nr ack-ului: 960990001
# Rtt-ul este: 14135216000si nr ack-ului: 960991501
# Rtt-ul este: 14147728000si nr ack-ului: 960993001
# Rtt-ul este: 14147728000si nr ack-ului: 960994501
# Rtt-ul este: 14160240000si nr ack-ului: 960996001
# Rtt-ul este: 14160240000si nr ack-ului: 960997501
# Rtt-ul este: 14172752000si nr ack-ului: 960999001
# Rtt-ul este: 14172752000si nr ack-ului: 961000501
# Rtt-ul este: 14185264000si nr ack-ului: 961002001
# Rtt-ul este: 14185264000si nr ack-ului: 961003501
# Rtt-ul este: 14197776000si nr ack-ului: 961005001
# Rtt-ul este: 14197776000si nr ack-ului: 961006501
# Rtt-ul este: 14210288000si nr ack-ului: 961008001
# Rtt-ul este: 14210288000si nr ack-ului: 961009501
# Rtt-ul este: 14222800000si nr ack-ului: 961011001
# Rtt-ul este: 14222800000si nr ack-ului: 961012501
# Rtt-ul este: 14235312000si nr ack-ului: 961014001
# Rtt-ul este: 14235312000si nr ack-ului: 961015501
# Rtt-ul este: 14247824000si nr ack-ului: 961017001
# Rtt-ul este: 14247824000si nr ack-ului: 961018501
# Rtt-ul este: 14260336000si nr ack-ului: 961020001
# Rtt-ul este: 14260336000si nr ack-ului: 961021501
# Rtt-ul este: 14272848000si nr ack-ului: 961023001
# Rtt-ul este: 14272848000si nr ack-ului: 961024501
# Rtt-ul este: 14285360000si nr ack-ului: 961026001
# Rtt-ul este: 14285360000si nr ack-ului: 961027501
# Rtt-ul este: 14297872000si nr ack-ului: 961029001
# Rtt-ul este: 14297872000si nr ack-ului: 961030501
# Rtt-ul este: 14310384000si nr ack-ului: 961032001
# Rtt-ul este: 14310384000si nr ack-ului: 961033501
# Rtt-ul este: 14322896000si nr ack-ului: 961035001
# Rtt-ul este: 14322896000si nr ack-ului: 961036501
# Rtt-ul este: 14335408000si nr ack-ului: 961038001
# Rtt-ul este: 14335408000si nr ack-ului: 961039501
# Rtt-ul este: 14347920000si nr ack-ului: 961041001
# Rtt-ul este: 14347920000si nr ack-ului: 961042501
# Rtt-ul este: 14360432000si nr ack-ului: 961044001
# Rtt-ul este: 14360432000si nr ack-ului: 961045501
# Rtt-ul este: 14372944000si nr ack-ului: 961047001
# Rtt-ul este: 14372944000si nr ack-ului: 961048501
# Rtt-ul este: 14385456000si nr ack-ului: 961050001
# Rtt-ul este: 14385456000si nr ack-ului: 961051501
# Rtt-ul este: 14397968000si nr ack-ului: 961053001
# Rtt-ul este: 14397968000si nr ack-ului: 961054501
# Rtt-ul este: 14410480000si nr ack-ului: 961056001
# Rtt-ul este: 14410480000si nr ack-ului: 961057501
# Rtt-ul este: 14422992000si nr ack-ului: 961059001
# Rtt-ul este: 14422992000si nr ack-ului: 961060501
# Rtt-ul este: 14435504000si nr ack-ului: 961062001
# Rtt-ul este: 14435504000si nr ack-ului: 961063501
# Rtt-ul este: 14448016000si nr ack-ului: 961065001
# Rtt-ul este: 14448016000si nr ack-ului: 961066501
# Rtt-ul este: 14460528000si nr ack-ului: 961068001
# Rtt-ul este: 14460528000si nr ack-ului: 961069501
# Rtt-ul este: 14473040000si nr ack-ului: 961071001
# Rtt-ul este: 14473040000si nr ack-ului: 961072501
# Rtt-ul este: 14485552000si nr ack-ului: 961074001
# Rtt-ul este: 14485552000si nr ack-ului: 961075501
# Rtt-ul este: 14498064000si nr ack-ului: 961077001
# Rtt-ul este: 14498064000si nr ack-ului: 961078501
# Rtt-ul este: 14510576000si nr ack-ului: 961080001
# Rtt-ul este: 14510576000si nr ack-ului: 961081501
# Rtt-ul este: 14523088000si nr ack-ului: 961083001
# Rtt-ul este: 14523088000si nr ack-ului: 961084501
# Rtt-ul este: 14535600000si nr ack-ului: 961086001
# Rtt-ul este: 14535600000si nr ack-ului: 961087501
# Rtt-ul este: 14548112000si nr ack-ului: 961089001
# Rtt-ul este: 14548112000si nr ack-ului: 961090501
# Rtt-ul este: 14560624000si nr ack-ului: 961092001
# Rtt-ul este: 14560624000si nr ack-ului: 961093501
# Rtt-ul este: 14573136000si nr ack-ului: 961095001
# Rtt-ul este: 14573136000si nr ack-ului: 961096501
# Rtt-ul este: 14585648000si nr ack-ului: 961098001
# Rtt-ul este: 14585648000si nr ack-ului: 961099501
# Rtt-ul este: 14598160000si nr ack-ului: 961101001
# Rtt-ul este: 14598160000si nr ack-ului: 961102501
# Rtt-ul este: 14610672000si nr ack-ului: 961104001
# Rtt-ul este: 14610672000si nr ack-ului: 961105501
# Rtt-ul este: 14623184000si nr ack-ului: 961107001
# Rtt-ul este: 14623184000si nr ack-ului: 961108501
# Rtt-ul este: 14635696000si nr ack-ului: 961110001
# Rtt-ul este: 14635696000si nr ack-ului: 961111501
# Rtt-ul este: 14648208000si nr ack-ului: 961113001
# Rtt-ul este: 14648208000si nr ack-ului: 961114501
# Rtt-ul este: 14660720000si nr ack-ului: 961116001
# Rtt-ul este: 14660720000si nr ack-ului: 961117501
# Rtt-ul este: 14673232000si nr ack-ului: 961119001
# Rtt-ul este: 14673232000si nr ack-ului: 961120501
# Rtt-ul este: 14685744000si nr ack-ului: 961122001
# Rtt-ul este: 14685744000si nr ack-ului: 961123501
# Rtt-ul este: 14698256000si nr ack-ului: 961125001
# Rtt-ul este: 14698256000si nr ack-ului: 961126501
# Rtt-ul este: 14710768000si nr ack-ului: 961128001
# Rtt-ul este: 14710768000si nr ack-ului: 961129501
# Rtt-ul este: 14723280000si nr ack-ului: 961131001
# Rtt-ul este: 14723280000si nr ack-ului: 961132501
# Rtt-ul este: 14735792000si nr ack-ului: 961134001
# Rtt-ul este: 14735792000si nr ack-ului: 961135501
# Rtt-ul este: 14748304000si nr ack-ului: 961137001
# Rtt-ul este: 14748304000si nr ack-ului: 961138501
# Rtt-ul este: 14760816000si nr ack-ului: 961140001
# Rtt-ul este: 14760816000si nr ack-ului: 961141501
# Rtt-ul este: 14773328000si nr ack-ului: 961143001
# Rtt-ul este: 14773328000si nr ack-ului: 961144501
# Rtt-ul este: 14785840000si nr ack-ului: 961146001
# Rtt-ul este: 14785840000si nr ack-ului: 961147501
# Rtt-ul este: 14798352000si nr ack-ului: 961149001
# Rtt-ul este: 14798352000si nr ack-ului: 961150501
# Rtt-ul este: 14810864000si nr ack-ului: 961152001
# Rtt-ul este: 14810864000si nr ack-ului: 961153501
# Rtt-ul este: 14823376000si nr ack-ului: 961155001
# Rtt-ul este: 14823376000si nr ack-ului: 961156501
# Rtt-ul este: 14835888000si nr ack-ului: 961158001
# Rtt-ul este: 14835888000si nr ack-ului: 961159501
# Rtt-ul este: 14848400000si nr ack-ului: 961161001
# Rtt-ul este: 14848400000si nr ack-ului: 961162501
# Rtt-ul este: 14860912000si nr ack-ului: 961164001
# Rtt-ul este: 14860912000si nr ack-ului: 961165501
# Rtt-ul este: 14873424000si nr ack-ului: 961167001
# Rtt-ul este: 14873424000si nr ack-ului: 961168501
# Rtt-ul este: 14885936000si nr ack-ului: 961170001
# Rtt-ul este: 14885936000si nr ack-ului: 961171501
# Rtt-ul este: 14898448000si nr ack-ului: 961173001
# Rtt-ul este: 14898448000si nr ack-ului: 961174501
# Rtt-ul este: 14910960000si nr ack-ului: 961176001
# Rtt-ul este: 14910960000si nr ack-ului: 961177501
# Rtt-ul este: 14923472000si nr ack-ului: 961179001
# Rtt-ul este: 14923472000si nr ack-ului: 961180501
# Rtt-ul este: 14935984000si nr ack-ului: 961182001
# Rtt-ul este: 14935984000si nr ack-ului: 961183501
# Rtt-ul este: 14948496000si nr ack-ului: 961185001
# Rtt-ul este: 14948496000si nr ack-ului: 961186501
# Rtt-ul este: 14961008000si nr ack-ului: 961188001
# Rtt-ul este: 14961008000si nr ack-ului: 961189501
# Rtt-ul este: 14973520000si nr ack-ului: 961191001
# Rtt-ul este: 14973520000si nr ack-ului: 961192501
# Rtt-ul este: 14986032000si nr ack-ului: 961194001
# Rtt-ul este: 14986032000si nr ack-ului: 961195501
# Rtt-ul este: 14998544000si nr ack-ului: 961197001
# Rtt-ul este: 14998544000si nr ack-ului: 961198501
# Rtt-ul este: 15011056000si nr ack-ului: 961200001
# Rtt-ul este: 15011056000si nr ack-ului: 961201501
# Rtt-ul este: 15023568000si nr ack-ului: 961203001
# Rtt-ul este: 15023568000si nr ack-ului: 961204501
# Rtt-ul este: 15036080000si nr ack-ului: 961206001
# Rtt-ul este: 15036080000si nr ack-ului: 961207501
# Rtt-ul este: 15048592000si nr ack-ului: 961209001
# Rtt-ul este: 15048592000si nr ack-ului: 961210501
# Rtt-ul este: 15061104000si nr ack-ului: 961212001
# Rtt-ul este: 15061104000si nr ack-ului: 961213501
# Rtt-ul este: 15073616000si nr ack-ului: 961215001
# Rtt-ul este: 15073616000si nr ack-ului: 961216501
# Rtt-ul este: 15086128000si nr ack-ului: 961218001
# Rtt-ul este: 15086128000si nr ack-ului: 961219501
# Rtt-ul este: 15098640000si nr ack-ului: 961221001
# Rtt-ul este: 15098640000si nr ack-ului: 961222501
# Rtt-ul este: 15111152000si nr ack-ului: 961224001
# Rtt-ul este: 15111152000si nr ack-ului: 961225501
# Rtt-ul este: 15123664000si nr ack-ului: 961227001
# Rtt-ul este: 15123664000si nr ack-ului: 961228501
# Rtt-ul este: 15136176000si nr ack-ului: 961230001
# Rtt-ul este: 15136176000si nr ack-ului: 961231501
# Rtt-ul este: 15148688000si nr ack-ului: 961233001
# Rtt-ul este: 15148688000si nr ack-ului: 961234501
# Rtt-ul este: 15161200000si nr ack-ului: 961236001
# Rtt-ul este: 15161200000si nr ack-ului: 961237501
# Rtt-ul este: 15173712000si nr ack-ului: 961239001
# Rtt-ul este: 15173712000si nr ack-ului: 961240501
# Rtt-ul este: 15186224000si nr ack-ului: 961242001
# Rtt-ul este: 15186224000si nr ack-ului: 961243501
# Rtt-ul este: 15198736000si nr ack-ului: 961245001
# Rtt-ul este: 15198736000si nr ack-ului: 961246501
# Rtt-ul este: 15211248000si nr ack-ului: 961248001
# Rtt-ul este: 15211248000si nr ack-ului: 961249501
# Rtt-ul este: 15223760000si nr ack-ului: 961251001
# Rtt-ul este: 15223760000si nr ack-ului: 961252501
# Rtt-ul este: 15236272000si nr ack-ului: 961254001
# Rtt-ul este: 15236272000si nr ack-ului: 961255501
# Rtt-ul este: 15248784000si nr ack-ului: 961257001
# Rtt-ul este: 15248784000si nr ack-ului: 961258501
# Rtt-ul este: 15261296000si nr ack-ului: 961260001
# Rtt-ul este: 15261296000si nr ack-ului: 961261501
# Rtt-ul este: 15273808000si nr ack-ului: 961263001
# Rtt-ul este: 15273808000si nr ack-ului: 961264501
# Rtt-ul este: 15286320000si nr ack-ului: 961266001
# Rtt-ul este: 15286320000si nr ack-ului: 961267501
# Rtt-ul este: 15298832000si nr ack-ului: 961269001
# Rtt-ul este: 15298832000si nr ack-ului: 961270501
# Rtt-ul este: 15311344000si nr ack-ului: 961272001
# Rtt-ul este: 15311344000si nr ack-ului: 961273501
# Rtt-ul este: 15323856000si nr ack-ului: 961275001
# Rtt-ul este: 15323856000si nr ack-ului: 961276501
# Rtt-ul este: 15336368000si nr ack-ului: 961278001
# Rtt-ul este: 15336368000si nr ack-ului: 961279501
# Rtt-ul este: 15348880000si nr ack-ului: 961281001
# Rtt-ul este: 15348880000si nr ack-ului: 961282501
# Rtt-ul este: 15361392000si nr ack-ului: 961284001
# Rtt-ul este: 15361392000si nr ack-ului: 961285501
# Rtt-ul este: 15373904000si nr ack-ului: 961287001
# Rtt-ul este: 15373904000si nr ack-ului: 961288501
# Rtt-ul este: 15386416000si nr ack-ului: 961290001
# Rtt-ul este: 15386416000si nr ack-ului: 961291501
# Rtt-ul este: 15398928000si nr ack-ului: 961293001
# Rtt-ul este: 15398928000si nr ack-ului: 961294501
# Rtt-ul este: 15411440000si nr ack-ului: 961296001
# Rtt-ul este: 15411440000si nr ack-ului: 961297501
# Rtt-ul este: 15423952000si nr ack-ului: 961299001
# Rtt-ul este: 15423952000si nr ack-ului: 961300501
# Rtt-ul este: 15436464000si nr ack-ului: 961302001
# Rtt-ul este: 15436464000si nr ack-ului: 961303501
# Rtt-ul este: 15448976000si nr ack-ului: 961305001
# Rtt-ul este: 15448976000si nr ack-ului: 961306501
# Rtt-ul este: 15461488000si nr ack-ului: 961308001
# Rtt-ul este: 15461488000si nr ack-ului: 961309501
# Rtt-ul este: 15474000000si nr ack-ului: 961311001
# Rtt-ul este: 15474000000si nr ack-ului: 961312501
# Rtt-ul este: 15486512000si nr ack-ului: 961314001
# Rtt-ul este: 15486512000si nr ack-ului: 961315501
# Rtt-ul este: 15499024000si nr ack-ului: 961317001
# Rtt-ul este: 15499024000si nr ack-ului: 961318501
# Rtt-ul este: 15511536000si nr ack-ului: 961320001
# Rtt-ul este: 15511536000si nr ack-ului: 961321501
# Rtt-ul este: 15524048000si nr ack-ului: 961323001
# Rtt-ul este: 15524048000si nr ack-ului: 961324501
# Rtt-ul este: 15536560000si nr ack-ului: 961326001
# Rtt-ul este: 15536560000si nr ack-ului: 961327501
# Rtt-ul este: 15549072000si nr ack-ului: 961329001
# Rtt-ul este: 15549072000si nr ack-ului: 961330501
# Rtt-ul este: 15561584000si nr ack-ului: 961332001
# Rtt-ul este: 15561584000si nr ack-ului: 961333501
# Rtt-ul este: 15574096000si nr ack-ului: 961335001
# Rtt-ul este: 15574096000si nr ack-ului: 961336501
# Rtt-ul este: 15586608000si nr ack-ului: 961338001
# Rtt-ul este: 15586608000si nr ack-ului: 961339501
# Rtt-ul este: 15599120000si nr ack-ului: 961341001
# Rtt-ul este: 15599120000si nr ack-ului: 961342501
# Rtt-ul este: 15611632000si nr ack-ului: 961344001
# Rtt-ul este: 15611632000si nr ack-ului: 961345501
# Rtt-ul este: 15624144000si nr ack-ului: 961347001
# Rtt-ul este: 15624144000si nr ack-ului: 961348501
# Rtt-ul este: 15636656000si nr ack-ului: 961350001
# Rtt-ul este: 15636656000si nr ack-ului: 961351501
# Rtt-ul este: 15649168000si nr ack-ului: 961353001
# Rtt-ul este: 15649168000si nr ack-ului: 961354501
# Rtt-ul este: 15661680000si nr ack-ului: 961356001
# Rtt-ul este: 15661680000si nr ack-ului: 961357501
# Rtt-ul este: 15674192000si nr ack-ului: 961359001
# Rtt-ul este: 15674192000si nr ack-ului: 961360501
# Rtt-ul este: 15686704000si nr ack-ului: 961362001
# Rtt-ul este: 15686704000si nr ack-ului: 961363501
# Rtt-ul este: 15699216000si nr ack-ului: 961365001
# Rtt-ul este: 15699216000si nr ack-ului: 961366501
# Rtt-ul este: 15711728000si nr ack-ului: 961368001
# Rtt-ul este: 15711728000si nr ack-ului: 961369501
# Rtt-ul este: 15724240000si nr ack-ului: 961371001
# Rtt-ul este: 15724240000si nr ack-ului: 961372501
# Rtt-ul este: 15736752000si nr ack-ului: 961374001
# Rtt-ul este: 15736752000si nr ack-ului: 961375501
# Rtt-ul este: 15749264000si nr ack-ului: 961377001
# Rtt-ul este: 15749264000si nr ack-ului: 961378501
# Rtt-ul este: 15761776000si nr ack-ului: 961380001
# Rtt-ul este: 15761776000si nr ack-ului: 961381501
# Rtt-ul este: 15774288000si nr ack-ului: 961383001
# Rtt-ul este: 15774288000si nr ack-ului: 961384501
# Rtt-ul este: 15786800000si nr ack-ului: 961386001
# Rtt-ul este: 15786800000si nr ack-ului: 961387501
# Rtt-ul este: 15799312000si nr ack-ului: 961389001
# Rtt-ul este: 15799312000si nr ack-ului: 961390501
# Rtt-ul este: 15811824000si nr ack-ului: 961392001
# Rtt-ul este: 15811824000si nr ack-ului: 961393501
# Rtt-ul este: 15824336000si nr ack-ului: 961395001
# Rtt-ul este: 15824336000si nr ack-ului: 961396501
# Rtt-ul este: 15836848000si nr ack-ului: 961398001
# Rtt-ul este: 15836848000si nr ack-ului: 961399501
# Rtt-ul este: 15849360000si nr ack-ului: 961401001
# Rtt-ul este: 15849360000si nr ack-ului: 961402501
# Rtt-ul este: 15861872000si nr ack-ului: 961404001
# Rtt-ul este: 15861872000si nr ack-ului: 961405501
# Rtt-ul este: 15874384000si nr ack-ului: 961407001
# Rtt-ul este: 15874384000si nr ack-ului: 961408501
# Rtt-ul este: 15886896000si nr ack-ului: 961410001
# Rtt-ul este: 15886896000si nr ack-ului: 961411501
# Rtt-ul este: 15899408000si nr ack-ului: 961413001
# Rtt-ul este: 15899408000si nr ack-ului: 961414501
# Rtt-ul este: 15911920000si nr ack-ului: 961416001
# Rtt-ul este: 15911920000si nr ack-ului: 961417501
# Rtt-ul este: 15924432000si nr ack-ului: 961419001
# Rtt-ul este: 15924432000si nr ack-ului: 961420501
# Rtt-ul este: 15936944000si nr ack-ului: 961422001
# Rtt-ul este: 15936944000si nr ack-ului: 961423501
# Rtt-ul este: 15949456000si nr ack-ului: 961425001
# Rtt-ul este: 15949456000si nr ack-ului: 961426501
# Rtt-ul este: 15961968000si nr ack-ului: 961428001
# Rtt-ul este: 15961968000si nr ack-ului: 961429501
# Rtt-ul este: 15974480000si nr ack-ului: 961431001
# Rtt-ul este: 15974480000si nr ack-ului: 961432501
# Rtt-ul este: 15986992000si nr ack-ului: 961434001
# Rtt-ul este: 15986992000si nr ack-ului: 961435501
# Rtt-ul este: 15999504000si nr ack-ului: 961437001
# Rtt-ul este: 15999504000si nr ack-ului: 961438501
# Rtt-ul este: 16012016000si nr ack-ului: 961440001
# Rtt-ul este: 16012016000si nr ack-ului: 961441501
# Rtt-ul este: 16024528000si nr ack-ului: 961443001
# Rtt-ul este: 16024528000si nr ack-ului: 961444501
# Rtt-ul este: 16037040000si nr ack-ului: 961446001
# Rtt-ul este: 16037040000si nr ack-ului: 961447501
# Rtt-ul este: 16049552000si nr ack-ului: 961449001
# Rtt-ul este: 16049552000si nr ack-ului: 961450501
# Rtt-ul este: 16062064000si nr ack-ului: 961452001
# Rtt-ul este: 16062064000si nr ack-ului: 961453501
# Rtt-ul este: 16074576000si nr ack-ului: 961455001
# Rtt-ul este: 16074576000si nr ack-ului: 961456501
# Rtt-ul este: 16087088000si nr ack-ului: 961458001
# Rtt-ul este: 16087088000si nr ack-ului: 961459501
# Rtt-ul este: 16099600000si nr ack-ului: 961461001
# Rtt-ul este: 16099600000si nr ack-ului: 961462501
# Rtt-ul este: 16112112000si nr ack-ului: 961464001
# Rtt-ul este: 16112112000si nr ack-ului: 961465501
# Rtt-ul este: 16124624000si nr ack-ului: 961467001
# Rtt-ul este: 16124624000si nr ack-ului: 961468501
# Rtt-ul este: 16137136000si nr ack-ului: 961470001
# Rtt-ul este: 16137136000si nr ack-ului: 961471501
# Rtt-ul este: 16149648000si nr ack-ului: 961473001
# Rtt-ul este: 16149648000si nr ack-ului: 961474501
# Rtt-ul este: 16162160000si nr ack-ului: 961476001
# Rtt-ul este: 16162160000si nr ack-ului: 961477501
# Rtt-ul este: 16174672000si nr ack-ului: 961479001
# Rtt-ul este: 16174672000si nr ack-ului: 961480501
# Rtt-ul este: 16187184000si nr ack-ului: 961482001
# Rtt-ul este: 16187184000si nr ack-ului: 961483501
# Rtt-ul este: 16199696000si nr ack-ului: 961485001
# Rtt-ul este: 16199696000si nr ack-ului: 961486501
# Rtt-ul este: 16212208000si nr ack-ului: 961488001
# Rtt-ul este: 16212208000si nr ack-ului: 961489501
# Rtt-ul este: 16224720000si nr ack-ului: 961491001
# Rtt-ul este: 16224720000si nr ack-ului: 961492501
# Rtt-ul este: 16237232000si nr ack-ului: 961494001
# Rtt-ul este: 16237232000si nr ack-ului: 961495501
# Rtt-ul este: 16249744000si nr ack-ului: 961497001
# Rtt-ul este: 16249744000si nr ack-ului: 961498501
# Rtt-ul este: 16262256000si nr ack-ului: 961500001
# Rtt-ul este: 16262256000si nr ack-ului: 961501501
# Rtt-ul este: 16274768000si nr ack-ului: 961503001
# Rtt-ul este: 16274768000si nr ack-ului: 961504501
# Rtt-ul este: 16287280000si nr ack-ului: 961506001
# Rtt-ul este: 16287280000si nr ack-ului: 961507501
# Rtt-ul este: 16299792000si nr ack-ului: 961509001
# Rtt-ul este: 16299792000si nr ack-ului: 961510501
# Rtt-ul este: 16312304000si nr ack-ului: 961512001
# Rtt-ul este: 16312304000si nr ack-ului: 961513501
# Rtt-ul este: 16324816000si nr ack-ului: 961515001
# Rtt-ul este: 16324816000si nr ack-ului: 961516501
# Rtt-ul este: 16337328000si nr ack-ului: 961518001
# Rtt-ul este: 16337328000si nr ack-ului: 961519501
# Rtt-ul este: 16349840000si nr ack-ului: 961521001
# Rtt-ul este: 16349840000si nr ack-ului: 961522501
# Rtt-ul este: 16362352000si nr ack-ului: 961524001
# Rtt-ul este: 16362352000si nr ack-ului: 961525501
# Rtt-ul este: 16374864000si nr ack-ului: 961527001
# Rtt-ul este: 16374864000si nr ack-ului: 961528501
# Rtt-ul este: 16387376000si nr ack-ului: 961530001
# Rtt-ul este: 16387376000si nr ack-ului: 961531501
# Rtt-ul este: 16399888000si nr ack-ului: 961533001
# Rtt-ul este: 16399888000si nr ack-ului: 961534501
# Rtt-ul este: 16412400000si nr ack-ului: 961536001
# Rtt-ul este: 16412400000si nr ack-ului: 961537501
# Rtt-ul este: 16424912000si nr ack-ului: 961539001
# Rtt-ul este: 16424912000si nr ack-ului: 961540501
# Rtt-ul este: 16437424000si nr ack-ului: 961542001
# Rtt-ul este: 16437424000si nr ack-ului: 961543501
# Rtt-ul este: 16449936000si nr ack-ului: 961545001
# Rtt-ul este: 16449936000si nr ack-ului: 961546501
# Rtt-ul este: 16462448000si nr ack-ului: 961548001
# Rtt-ul este: 16462448000si nr ack-ului: 961549501
# Rtt-ul este: 16474960000si nr ack-ului: 961551001
# Rtt-ul este: 16474960000si nr ack-ului: 961552501
# Rtt-ul este: 16487472000si nr ack-ului: 961554001
# Rtt-ul este: 16487472000si nr ack-ului: 961555501
# Rtt-ul este: 16499984000si nr ack-ului: 961557001
# Rtt-ul este: 16499984000si nr ack-ului: 961558501
# Rtt-ul este: 16512496000si nr ack-ului: 961560001
# Rtt-ul este: 16512496000si nr ack-ului: 961561501
# Rtt-ul este: 16525008000si nr ack-ului: 961563001
# Rtt-ul este: 16525008000si nr ack-ului: 961564501
# Rtt-ul este: 16537520000si nr ack-ului: 961566001
# Rtt-ul este: 16537520000si nr ack-ului: 961567501
# Rtt-ul este: 16550032000si nr ack-ului: 961569001
# Rtt-ul este: 16550032000si nr ack-ului: 961570501
# Rtt-ul este: 16562544000si nr ack-ului: 961572001
# Rtt-ul este: 16562544000si nr ack-ului: 961573501
# Rtt-ul este: 16575056000si nr ack-ului: 961575001
# Rtt-ul este: 16575056000si nr ack-ului: 961576501
# Rtt-ul este: 16587568000si nr ack-ului: 961578001
# Rtt-ul este: 16587568000si nr ack-ului: 961579501
# Rtt-ul este: 16600080000si nr ack-ului: 961581001
# Rtt-ul este: 16600080000si nr ack-ului: 961582501
# Rtt-ul este: 16612592000si nr ack-ului: 961584001
# Rtt-ul este: 16612592000si nr ack-ului: 961585501
# Rtt-ul este: 16625104000si nr ack-ului: 961587001
# Rtt-ul este: 16625104000si nr ack-ului: 961588501
# Rtt-ul este: 16625104000si nr ack-ului: 961590001
# Rtt-ul este: 16625104000si nr ack-ului: 961591501
# Rtt-ul este: 16625104000si nr ack-ului: 961593001
# Rtt-ul este: 16625104000si nr ack-ului: 961594501
# Rtt-ul este: 16625104000si nr ack-ului: 961596001
# Rtt-ul este: 16625104000si nr ack-ului: 961597501
# Rtt-ul este: 16625104000si nr ack-ului: 961599001
# Rtt-ul este: 16625104000si nr ack-ului: 961600501
# Rtt-ul este: 16625104000si nr ack-ului: 961602001
# Rtt-ul este: 16625104000si nr ack-ului: 961603501
# Rtt-ul este: 16625104000si nr ack-ului: 961605001
# Rtt-ul este: 16625104000si nr ack-ului: 961606501
# Rtt-ul este: 16625104000si nr ack-ului: 961608001
# Rtt-ul este: 16625104000si nr ack-ului: 961609501
# Rtt-ul este: 16625104000si nr ack-ului: 961611001
# Rtt-ul este: 16625104000si nr ack-ului: 961612501
# Rtt-ul este: 16625104000si nr ack-ului: 961614001
# Rtt-ul este: 16625104000si nr ack-ului: 961615501
# Rtt-ul este: 16625104000si nr ack-ului: 961617001
# Rtt-ul este: 16625104000si nr ack-ului: 961618501
# Rtt-ul este: 16625104000si nr ack-ului: 961620001
# Rtt-ul este: 16625104000si nr ack-ului: 961621501
# Rtt-ul este: 16625104000si nr ack-ului: 961623001
# Rtt-ul este: 16625104000si nr ack-ului: 961624501
# Rtt-ul este: 16625104000si nr ack-ului: 961626001
# Rtt-ul este: 16625104000si nr ack-ului: 961627501
# Rtt-ul este: 16625104000si nr ack-ului: 961629001
# Rtt-ul este: 16625104000si nr ack-ului: 961630501
# Rtt-ul este: 16625104000si nr ack-ului: 961632001
# Rtt-ul este: 16625104000si nr ack-ului: 961633501
# Rtt-ul este: 16625104000si nr ack-ului: 961635001
# Rtt-ul este: 16625104000si nr ack-ului: 112411501
# Rtt-ul este: 16625104000si nr ack-ului: 112413001
# Rtt-ul este: 16637616000si nr ack-ului: 112414501
# Rtt-ul este: 16637616000si nr ack-ului: 112416001
# Rtt-ul este: 16650128000si nr ack-ului: 112417501
# Rtt-ul este: 16650128000si nr ack-ului: 112419001
# Rtt-ul este: 16662640000si nr ack-ului: 112420501
# Rtt-ul este: 16662640000si nr ack-ului: 112422001
# Rtt-ul este: 16675152000si nr ack-ului: 112423501
# Rtt-ul este: 16675152000si nr ack-ului: 112425001
# Rtt-ul este: 16687664000si nr ack-ului: 112426501
# Rtt-ul este: 16687664000si nr ack-ului: 112428001
# Rtt-ul este: 16700176000si nr ack-ului: 112429501
# Rtt-ul este: 16700176000si nr ack-ului: 112431001
# Rtt-ul este: 16712688000si nr ack-ului: 112432501
# Rtt-ul este: 16712688000si nr ack-ului: 112434001
# Rtt-ul este: 16725200000si nr ack-ului: 112435501
# Rtt-ul este: 16725200000si nr ack-ului: 112437001
# Rtt-ul este: 16737712000si nr ack-ului: 112438501
# Rtt-ul este: 16737712000si nr ack-ului: 112440001
# Rtt-ul este: 16750224000si nr ack-ului: 112441501
# Rtt-ul este: 16750224000si nr ack-ului: 112443001
# Rtt-ul este: 16762736000si nr ack-ului: 112444501
# Rtt-ul este: 16762736000si nr ack-ului: 112446001
# Rtt-ul este: 16775248000si nr ack-ului: 112447501
# Rtt-ul este: 16775248000si nr ack-ului: 112449001
# Rtt-ul este: 16787760000si nr ack-ului: 112450501
# Rtt-ul este: 16787760000si nr ack-ului: 112452001
# Rtt-ul este: 16800272000si nr ack-ului: 112453501
# Rtt-ul este: 16800272000si nr ack-ului: 112455001
# Rtt-ul este: 16812784000si nr ack-ului: 112456501
# Rtt-ul este: 16812784000si nr ack-ului: 112458001
# Rtt-ul este: 16825296000si nr ack-ului: 112459501
# Rtt-ul este: 16825296000si nr ack-ului: 112461001
# Rtt-ul este: 16837808000si nr ack-ului: 112462501
# Rtt-ul este: 16837808000si nr ack-ului: 112464001
# Rtt-ul este: 16850320000si nr ack-ului: 112465501
# Rtt-ul este: 16850320000si nr ack-ului: 112467001
# Rtt-ul este: 16862832000si nr ack-ului: 112468501
# Rtt-ul este: 16862832000si nr ack-ului: 112470001
# Rtt-ul este: 16875344000si nr ack-ului: 112471501
# Rtt-ul este: 16875344000si nr ack-ului: 112473001
# Rtt-ul este: 16887856000si nr ack-ului: 112474501
# Rtt-ul este: 16887856000si nr ack-ului: 112476001
# Rtt-ul este: 16900368000si nr ack-ului: 112477501
# Rtt-ul este: 16900368000si nr ack-ului: 112479001
# Rtt-ul este: 16912880000si nr ack-ului: 112480501
# Rtt-ul este: 16912880000si nr ack-ului: 112482001
# Rtt-ul este: 16925392000si nr ack-ului: 112483501
# Rtt-ul este: 16925392000si nr ack-ului: 112485001
# Rtt-ul este: 16937904000si nr ack-ului: 112486501
# Rtt-ul este: 16937904000si nr ack-ului: 112488001
# Rtt-ul este: 16950416000si nr ack-ului: 112489501
# Rtt-ul este: 16950416000si nr ack-ului: 112491001
# Rtt-ul este: 16962928000si nr ack-ului: 112492501
# Rtt-ul este: 16962928000si nr ack-ului: 112494001
# Rtt-ul este: 16975440000si nr ack-ului: 112495501
# Rtt-ul este: 16975440000si nr ack-ului: 112497001
# Rtt-ul este: 16987952000si nr ack-ului: 112498501
# Rtt-ul este: 16987952000si nr ack-ului: 112500001
# Rtt-ul este: 17000464000si nr ack-ului: 112501501
# Rtt-ul este: 17000464000si nr ack-ului: 112503001
# Rtt-ul este: 17012976000si nr ack-ului: 112504501
# Rtt-ul este: 17012976000si nr ack-ului: 112506001
# Rtt-ul este: 17025488000si nr ack-ului: 112507501
# Rtt-ul este: 17025488000si nr ack-ului: 112509001
# Rtt-ul este: 17038000000si nr ack-ului: 112510501
# Rtt-ul este: 17038000000si nr ack-ului: 112512001
# Rtt-ul este: 17050512000si nr ack-ului: 112513501
# Rtt-ul este: 17050512000si nr ack-ului: 112515001
# Rtt-ul este: 17063024000si nr ack-ului: 112516501
# Rtt-ul este: 17063024000si nr ack-ului: 112518001
# Rtt-ul este: 17075536000si nr ack-ului: 112519501
# Rtt-ul este: 17075536000si nr ack-ului: 112521001
# Rtt-ul este: 17088048000si nr ack-ului: 112522501
# Rtt-ul este: 17088048000si nr ack-ului: 112524001
# Rtt-ul este: 17100560000si nr ack-ului: 112525501
# Rtt-ul este: 17100560000si nr ack-ului: 112527001
# Rtt-ul este: 17113072000si nr ack-ului: 112528501
# Rtt-ul este: 17113072000si nr ack-ului: 112530001
# Rtt-ul este: 17125584000si nr ack-ului: 112531501
# Rtt-ul este: 17125584000si nr ack-ului: 112533001
# Rtt-ul este: 17138096000si nr ack-ului: 112534501
# Rtt-ul este: 17138096000si nr ack-ului: 112536001
# Rtt-ul este: 17150608000si nr ack-ului: 112537501
# Rtt-ul este: 17150608000si nr ack-ului: 112539001
# Rtt-ul este: 17163120000si nr ack-ului: 112540501
# Rtt-ul este: 17163120000si nr ack-ului: 112542001
# Rtt-ul este: 17175632000si nr ack-ului: 112543501
# Rtt-ul este: 17175632000si nr ack-ului: 112545001
# Rtt-ul este: 17188144000si nr ack-ului: 112546501
# Rtt-ul este: 17188144000si nr ack-ului: 112548001
# Rtt-ul este: 17200656000si nr ack-ului: 112549501
# Rtt-ul este: 17200656000si nr ack-ului: 112551001
# Rtt-ul este: 17213168000si nr ack-ului: 112552501
# Rtt-ul este: 17213168000si nr ack-ului: 112554001
# Rtt-ul este: 17225680000si nr ack-ului: 112555501
# Rtt-ul este: 17225680000si nr ack-ului: 112557001
# Rtt-ul este: 17238192000si nr ack-ului: 112558501
# Rtt-ul este: 17238192000si nr ack-ului: 112560001
# Rtt-ul este: 17250704000si nr ack-ului: 112561501
# Rtt-ul este: 17250704000si nr ack-ului: 112563001
# Rtt-ul este: 17263216000si nr ack-ului: 112564501
# Rtt-ul este: 17263216000si nr ack-ului: 112566001
# Rtt-ul este: 17275728000si nr ack-ului: 112567501
# Rtt-ul este: 17275728000si nr ack-ului: 112569001
# Rtt-ul este: 17288240000si nr ack-ului: 112570501
# Rtt-ul este: 17288240000si nr ack-ului: 112572001
# Rtt-ul este: 17300752000si nr ack-ului: 112573501
# Rtt-ul este: 17300752000si nr ack-ului: 112575001
# Rtt-ul este: 17313264000si nr ack-ului: 112576501
# Rtt-ul este: 17313264000si nr ack-ului: 112578001
# Rtt-ul este: 17325776000si nr ack-ului: 112579501
# Rtt-ul este: 17325776000si nr ack-ului: 112581001
# Rtt-ul este: 17338288000si nr ack-ului: 112582501
# Rtt-ul este: 17338288000si nr ack-ului: 112584001
# Rtt-ul este: 17350800000si nr ack-ului: 112585501
# Rtt-ul este: 17350800000si nr ack-ului: 112587001
# Rtt-ul este: 17363312000si nr ack-ului: 112588501
# Rtt-ul este: 17363312000si nr ack-ului: 112590001
# Rtt-ul este: 17375824000si nr ack-ului: 112591501
# Rtt-ul este: 17375824000si nr ack-ului: 112593001
# Rtt-ul este: 17388336000si nr ack-ului: 112594501
# Rtt-ul este: 17388336000si nr ack-ului: 112596001
# Rtt-ul este: 17400848000si nr ack-ului: 112597501
# Rtt-ul este: 17400848000si nr ack-ului: 112599001
# Rtt-ul este: 17413360000si nr ack-ului: 112600501
# Rtt-ul este: 17413360000si nr ack-ului: 112602001
# Rtt-ul este: 17425872000si nr ack-ului: 112603501
# Rtt-ul este: 17425872000si nr ack-ului: 112605001
# Rtt-ul este: 17438384000si nr ack-ului: 112606501
# Rtt-ul este: 17438384000si nr ack-ului: 112608001
# Rtt-ul este: 17450896000si nr ack-ului: 112609501
# Rtt-ul este: 17450896000si nr ack-ului: 112611001
# Rtt-ul este: 17463408000si nr ack-ului: 112612501
# Rtt-ul este: 17463408000si nr ack-ului: 112614001
# Rtt-ul este: 17475920000si nr ack-ului: 112615501
# Rtt-ul este: 17475920000si nr ack-ului: 112617001
# Rtt-ul este: 17488432000si nr ack-ului: 112618501
# Rtt-ul este: 17488432000si nr ack-ului: 112620001
# Rtt-ul este: 17500944000si nr ack-ului: 112621501
# Rtt-ul este: 17500944000si nr ack-ului: 112623001
# Rtt-ul este: 17513456000si nr ack-ului: 112624501
# Rtt-ul este: 17513456000si nr ack-ului: 112626001
# Rtt-ul este: 17525968000si nr ack-ului: 112627501
# Rtt-ul este: 17525968000si nr ack-ului: 112629001
# Rtt-ul este: 17538480000si nr ack-ului: 112630501
# Rtt-ul este: 17538480000si nr ack-ului: 112632001
# Rtt-ul este: 17550992000si nr ack-ului: 112633501
# Rtt-ul este: 17550992000si nr ack-ului: 112635001
# Rtt-ul este: 17563504000si nr ack-ului: 112636501
# Rtt-ul este: 17563504000si nr ack-ului: 112638001
# Rtt-ul este: 17576016000si nr ack-ului: 112639501
# Rtt-ul este: 17576016000si nr ack-ului: 112641001
# Rtt-ul este: 17588528000si nr ack-ului: 112642501
# Rtt-ul este: 17588528000si nr ack-ului: 112644001
# Rtt-ul este: 17601040000si nr ack-ului: 112645501
# Rtt-ul este: 17601040000si nr ack-ului: 112647001
# Rtt-ul este: 17613552000si nr ack-ului: 112648501
# Rtt-ul este: 17613552000si nr ack-ului: 112650001
# Rtt-ul este: 17626064000si nr ack-ului: 112651501
# Rtt-ul este: 17626064000si nr ack-ului: 112653001
# Rtt-ul este: 17638576000si nr ack-ului: 112654501
# Rtt-ul este: 17638576000si nr ack-ului: 112656001
# Rtt-ul este: 17651088000si nr ack-ului: 112657501
# Rtt-ul este: 17651088000si nr ack-ului: 112659001
# Rtt-ul este: 17663600000si nr ack-ului: 112660501
# Rtt-ul este: 17663600000si nr ack-ului: 112662001
# Rtt-ul este: 17676112000si nr ack-ului: 112663501
# Rtt-ul este: 17676112000si nr ack-ului: 112665001
# Rtt-ul este: 17688624000si nr ack-ului: 112666501
# Rtt-ul este: 17688624000si nr ack-ului: 112668001
# Rtt-ul este: 17701136000si nr ack-ului: 112669501
# Rtt-ul este: 17701136000si nr ack-ului: 112671001
# Rtt-ul este: 17713648000si nr ack-ului: 112672501
# Rtt-ul este: 17713648000si nr ack-ului: 112674001
# Rtt-ul este: 17726160000si nr ack-ului: 112675501
# Rtt-ul este: 17726160000si nr ack-ului: 112677001
# Rtt-ul este: 17738672000si nr ack-ului: 112678501
# Rtt-ul este: 17738672000si nr ack-ului: 112680001
# Rtt-ul este: 17751184000si nr ack-ului: 112681501
# Rtt-ul este: 17751184000si nr ack-ului: 112683001
# Rtt-ul este: 17763696000si nr ack-ului: 112684501
# Rtt-ul este: 17763696000si nr ack-ului: 112686001
# Rtt-ul este: 17776208000si nr ack-ului: 112687501
# Rtt-ul este: 17776208000si nr ack-ului: 112689001
# Rtt-ul este: 17788720000si nr ack-ului: 112690501
# Rtt-ul este: 17788720000si nr ack-ului: 112692001
# Rtt-ul este: 17801232000si nr ack-ului: 112693501
# Rtt-ul este: 17801232000si nr ack-ului: 112695001
# Rtt-ul este: 17813744000si nr ack-ului: 112696501
# Rtt-ul este: 17813744000si nr ack-ului: 112698001
# Rtt-ul este: 17826256000si nr ack-ului: 112699501
# Rtt-ul este: 17826256000si nr ack-ului: 112701001
# Rtt-ul este: 17838768000si nr ack-ului: 112702501
# Rtt-ul este: 17838768000si nr ack-ului: 112704001
# Rtt-ul este: 17851280000si nr ack-ului: 112705501
# Rtt-ul este: 17851280000si nr ack-ului: 112707001
# Rtt-ul este: 17863792000si nr ack-ului: 112708501
# Rtt-ul este: 17863792000si nr ack-ului: 112710001
# Rtt-ul este: 17876304000si nr ack-ului: 112711501
# ...
# Rtt-ul este: 12308464000si nr ack-ului: 973281001
# Rtt-ul este: 12320976000si nr ack-ului: 973282501
# Rtt-ul este: 12320976000si nr ack-ului: 973284001
# Rtt-ul este: 12333488000si nr ack-ului: 973285501
# Rtt-ul este: 12333488000si nr ack-ului: 973287001
# Rtt-ul este: 12346000000si nr ack-ului: 973288501
# Rtt-ul este: 12346000000si nr ack-ului: 973290001
# Rtt-ul este: 12358512000si nr ack-ului: 973291501
# Rtt-ul este: 12358512000si nr ack-ului: 973293001
# Rtt-ul este: 12371024000si nr ack-ului: 973294501
# Rtt-ul este: 12371024000si nr ack-ului: 973296001
# Rtt-ul este: 12383536000si nr ack-ului: 973297501
# Rtt-ul este: 12383536000si nr ack-ului: 973299001
# Rtt-ul este: 12396048000si nr ack-ului: 973300501
# Rtt-ul este: 12396048000si nr ack-ului: 973302001
# Rtt-ul este: 12408560000si nr ack-ului: 973303501
# Rtt-ul este: 12408560000si nr ack-ului: 973305001
# Rtt-ul este: 12421072000si nr ack-ului: 973306501
# Rtt-ul este: 12421072000si nr ack-ului: 973308001
# Rtt-ul este: 12433584000si nr ack-ului: 973309501
# Rtt-ul este: 12433584000si nr ack-ului: 973311001
# Rtt-ul este: 12446096000si nr ack-ului: 973312501
# Rtt-ul este: 12446096000si nr ack-ului: 973314001
# Rtt-ul este: 12458608000si nr ack-ului: 973315501
# Rtt-ul este: 12458608000si nr ack-ului: 973317001
# Rtt-ul este: 12471120000si nr ack-ului: 973318501
# Rtt-ul este: 12471120000si nr ack-ului: 973320001
# Rtt-ul este: 12483632000si nr ack-ului: 973321501
# Rtt-ul este: 12483632000si nr ack-ului: 973323001
# Rtt-ul este: 12496144000si nr ack-ului: 973324501
# Rtt-ul este: 12496144000si nr ack-ului: 973326001
# Rtt-ul este: 12508656000si nr ack-ului: 973327501
# Rtt-ul este: 12508656000si nr ack-ului: 973329001
# Rtt-ul este: 12521168000si nr ack-ului: 973330501
# Rtt-ul este: 12521168000si nr ack-ului: 973332001
# Rtt-ul este: 12533680000si nr ack-ului: 973333501
# Rtt-ul este: 12533680000si nr ack-ului: 973335001
# Rtt-ul este: 12546192000si nr ack-ului: 973336501
# Rtt-ul este: 12546192000si nr ack-ului: 973338001
# Rtt-ul este: 12558704000si nr ack-ului: 973339501
# Rtt-ul este: 12558704000si nr ack-ului: 973341001
# Rtt-ul este: 12571216000si nr ack-ului: 973342501
# Rtt-ul este: 12571216000si nr ack-ului: 973344001
# Rtt-ul este: 12583728000si nr ack-ului: 973345501
# Rtt-ul este: 12583728000si nr ack-ului: 973347001
# Rtt-ul este: 12596240000si nr ack-ului: 973348501
# Rtt-ul este: 12596240000si nr ack-ului: 973350001
# Rtt-ul este: 12608752000si nr ack-ului: 973351501
# Rtt-ul este: 12608752000si nr ack-ului: 973353001
# Rtt-ul este: 12621264000si nr ack-ului: 973354501
# Rtt-ul este: 12621264000si nr ack-ului: 973356001
# Rtt-ul este: 12633776000si nr ack-ului: 973357501
# Rtt-ul este: 12633776000si nr ack-ului: 973359001
# Rtt-ul este: 12646288000si nr ack-ului: 973360501
# Rtt-ul este: 12646288000si nr ack-ului: 973362001
# Rtt-ul este: 12658800000si nr ack-ului: 973363501
# Rtt-ul este: 12658800000si nr ack-ului: 973365001
# Rtt-ul este: 12671312000si nr ack-ului: 973366501
# Rtt-ul este: 12671312000si nr ack-ului: 973368001
# Rtt-ul este: 12683824000si nr ack-ului: 973369501
# Rtt-ul este: 12683824000si nr ack-ului: 973371001
# Rtt-ul este: 12696336000si nr ack-ului: 973372501
# Rtt-ul este: 12696336000si nr ack-ului: 973374001
# Rtt-ul este: 12708848000si nr ack-ului: 973375501
# Rtt-ul este: 12708848000si nr ack-ului: 973377001
# Rtt-ul este: 12721360000si nr ack-ului: 973378501
# Rtt-ul este: 12721360000si nr ack-ului: 973380001
# Rtt-ul este: 12733872000si nr ack-ului: 973381501
# Rtt-ul este: 12733872000si nr ack-ului: 973383001
# Rtt-ul este: 12746384000si nr ack-ului: 973384501
# Rtt-ul este: 12746384000si nr ack-ului: 973386001
# Rtt-ul este: 12758896000si nr ack-ului: 973387501
# Rtt-ul este: 12758896000si nr ack-ului: 973389001
# Rtt-ul este: 12771408000si nr ack-ului: 973390501
# Rtt-ul este: 12771408000si nr ack-ului: 973392001
# Rtt-ul este: 12783920000si nr ack-ului: 973393501
# Rtt-ul este: 12783920000si nr ack-ului: 973395001
# Rtt-ul este: 12796432000si nr ack-ului: 973396501
# Rtt-ul este: 12796432000si nr ack-ului: 973398001
# Rtt-ul este: 12808944000si nr ack-ului: 973399501
# Rtt-ul este: 12808944000si nr ack-ului: 973401001
# Rtt-ul este: 12821456000si nr ack-ului: 973402501
# Rtt-ul este: 12821456000si nr ack-ului: 973404001
# Rtt-ul este: 12833968000si nr ack-ului: 973405501
# Rtt-ul este: 12833968000si nr ack-ului: 973407001
# Rtt-ul este: 12846480000si nr ack-ului: 973408501
# Rtt-ul este: 12846480000si nr ack-ului: 973410001
# Rtt-ul este: 12858992000si nr ack-ului: 973411501
# Rtt-ul este: 12858992000si nr ack-ului: 973413001
# Rtt-ul este: 12871504000si nr ack-ului: 973414501
# Rtt-ul este: 12871504000si nr ack-ului: 973416001
# Rtt-ul este: 12884016000si nr ack-ului: 973417501
# Rtt-ul este: 12884016000si nr ack-ului: 973419001
# Rtt-ul este: 12896528000si nr ack-ului: 973420501
# Rtt-ul este: 12896528000si nr ack-ului: 973422001
# Rtt-ul este: 12909040000si nr ack-ului: 973423501
# Rtt-ul este: 12909040000si nr ack-ului: 973425001
# Rtt-ul este: 12921552000si nr ack-ului: 973426501
# Rtt-ul este: 12921552000si nr ack-ului: 973428001
# Rtt-ul este: 12934064000si nr ack-ului: 973429501
# Rtt-ul este: 12934064000si nr ack-ului: 973431001
# Rtt-ul este: 12946576000si nr ack-ului: 973432501
# Rtt-ul este: 12946576000si nr ack-ului: 973434001
# Rtt-ul este: 12959088000si nr ack-ului: 973435501
# Rtt-ul este: 12959088000si nr ack-ului: 973437001
# Rtt-ul este: 12971600000si nr ack-ului: 973438501
# Rtt-ul este: 12971600000si nr ack-ului: 973440001
# Rtt-ul este: 12984112000si nr ack-ului: 973441501
# Rtt-ul este: 12984112000si nr ack-ului: 973443001
# Rtt-ul este: 12996624000si nr ack-ului: 973444501
# Rtt-ul este: 12996624000si nr ack-ului: 973446001
# Rtt-ul este: 13009136000si nr ack-ului: 973447501
# Rtt-ul este: 13009136000si nr ack-ului: 973449001
# Rtt-ul este: 13021648000si nr ack-ului: 973450501
# Rtt-ul este: 13021648000si nr ack-ului: 973452001
# Rtt-ul este: 13034160000si nr ack-ului: 973453501
# Rtt-ul este: 13034160000si nr ack-ului: 973455001
# Rtt-ul este: 13046672000si nr ack-ului: 973456501
# Rtt-ul este: 13046672000si nr ack-ului: 973458001
# Rtt-ul este: 13059184000si nr ack-ului: 973459501
# Rtt-ul este: 13059184000si nr ack-ului: 973461001
# Rtt-ul este: 13071696000si nr ack-ului: 973462501
# Rtt-ul este: 13071696000si nr ack-ului: 973464001
# Rtt-ul este: 13084208000si nr ack-ului: 973465501
# Rtt-ul este: 13084208000si nr ack-ului: 973467001
# Rtt-ul este: 13096720000si nr ack-ului: 973468501
# Rtt-ul este: 13096720000si nr ack-ului: 973470001
# Rtt-ul este: 13109232000si nr ack-ului: 973471501
# Rtt-ul este: 13109232000si nr ack-ului: 973473001
# Rtt-ul este: 13121744000si nr ack-ului: 973474501
# Rtt-ul este: 13121744000si nr ack-ului: 973476001
# Rtt-ul este: 13134256000si nr ack-ului: 973477501
# Rtt-ul este: 13134256000si nr ack-ului: 973479001
# Rtt-ul este: 13146768000si nr ack-ului: 973480501
# Rtt-ul este: 13146768000si nr ack-ului: 973482001
# Rtt-ul este: 13159280000si nr ack-ului: 973483501
# Rtt-ul este: 13159280000si nr ack-ului: 973485001
# Rtt-ul este: 13171792000si nr ack-ului: 973486501
# Rtt-ul este: 13171792000si nr ack-ului: 973488001
# Rtt-ul este: 13184304000si nr ack-ului: 973489501
# Rtt-ul este: 13184304000si nr ack-ului: 973491001
# Rtt-ul este: 13196816000si nr ack-ului: 973492501
# Rtt-ul este: 13196816000si nr ack-ului: 973494001
# Rtt-ul este: 13209328000si nr ack-ului: 973495501
# Rtt-ul este: 13209328000si nr ack-ului: 973497001
# Rtt-ul este: 13221840000si nr ack-ului: 973498501
# Rtt-ul este: 13221840000si nr ack-ului: 973500001
# Rtt-ul este: 13234352000si nr ack-ului: 973501501
# Rtt-ul este: 13234352000si nr ack-ului: 973503001
# Rtt-ul este: 13246864000si nr ack-ului: 973504501
# Rtt-ul este: 13246864000si nr ack-ului: 973506001
# Rtt-ul este: 13259376000si nr ack-ului: 973507501
# Rtt-ul este: 13259376000si nr ack-ului: 973509001
# Rtt-ul este: 13271888000si nr ack-ului: 973510501
# Rtt-ul este: 13271888000si nr ack-ului: 973512001
# Rtt-ul este: 13284400000si nr ack-ului: 973513501
# Rtt-ul este: 13284400000si nr ack-ului: 973515001
# Rtt-ul este: 13296912000si nr ack-ului: 973516501
# Rtt-ul este: 13296912000si nr ack-ului: 973518001
# Rtt-ul este: 13309424000si nr ack-ului: 973519501
# Rtt-ul este: 13309424000si nr ack-ului: 973521001
# Rtt-ul este: 13321936000si nr ack-ului: 973522501
# Rtt-ul este: 13321936000si nr ack-ului: 973524001
# Rtt-ul este: 13334448000si nr ack-ului: 973525501
# Rtt-ul este: 13334448000si nr ack-ului: 973527001
# Rtt-ul este: 13346960000si nr ack-ului: 973528501
# Rtt-ul este: 13346960000si nr ack-ului: 973530001
# Rtt-ul este: 13359472000si nr ack-ului: 973531501
# Rtt-ul este: 13359472000si nr ack-ului: 973533001
# Rtt-ul este: 13371984000si nr ack-ului: 973534501
# Rtt-ul este: 13371984000si nr ack-ului: 973536001
# Rtt-ul este: 13384496000si nr ack-ului: 973537501
# Rtt-ul este: 13384496000si nr ack-ului: 973539001
# Rtt-ul este: 13397008000si nr ack-ului: 973540501
# Rtt-ul este: 13397008000si nr ack-ului: 973542001
# Rtt-ul este: 13409520000si nr ack-ului: 973543501
# Rtt-ul este: 13409520000si nr ack-ului: 973545001
# Rtt-ul este: 13422032000si nr ack-ului: 973546501
# Rtt-ul este: 13422032000si nr ack-ului: 973548001
# Rtt-ul este: 13434544000si nr ack-ului: 973549501
# Rtt-ul este: 13434544000si nr ack-ului: 973551001
# Rtt-ul este: 13447056000si nr ack-ului: 973552501
# Rtt-ul este: 13447056000si nr ack-ului: 973554001
# Rtt-ul este: 13459568000si nr ack-ului: 973555501
# Rtt-ul este: 13459568000si nr ack-ului: 973557001
# Rtt-ul este: 13472080000si nr ack-ului: 973558501
# Rtt-ul este: 13472080000si nr ack-ului: 973560001
# Rtt-ul este: 13484592000si nr ack-ului: 973561501
# Rtt-ul este: 13484592000si nr ack-ului: 973563001
# Rtt-ul este: 13497104000si nr ack-ului: 973564501
# Rtt-ul este: 13497104000si nr ack-ului: 973566001
# Rtt-ul este: 13509616000si nr ack-ului: 973567501
# Rtt-ul este: 13509616000si nr ack-ului: 973569001
# Rtt-ul este: 13522128000si nr ack-ului: 973570501
# Rtt-ul este: 13522128000si nr ack-ului: 973572001
# Rtt-ul este: 13534640000si nr ack-ului: 973573501
# Rtt-ul este: 13534640000si nr ack-ului: 973575001
# Rtt-ul este: 13547152000si nr ack-ului: 973576501
# Rtt-ul este: 13547152000si nr ack-ului: 973578001
# Rtt-ul este: 13559664000si nr ack-ului: 973579501
# Rtt-ul este: 13559664000si nr ack-ului: 973581001
# Rtt-ul este: 13572176000si nr ack-ului: 973582501
# Rtt-ul este: 13572176000si nr ack-ului: 973584001
# Rtt-ul este: 13584688000si nr ack-ului: 973585501
# Rtt-ul este: 13584688000si nr ack-ului: 973587001
# Rtt-ul este: 13597200000si nr ack-ului: 973588501
# Rtt-ul este: 13597200000si nr ack-ului: 973590001
# Rtt-ul este: 13609712000si nr ack-ului: 973591501
# Rtt-ul este: 13609712000si nr ack-ului: 973593001
# Rtt-ul este: 13622224000si nr ack-ului: 973594501
# Rtt-ul este: 13622224000si nr ack-ului: 973596001
# Rtt-ul este: 13634736000si nr ack-ului: 973597501
# Rtt-ul este: 13634736000si nr ack-ului: 973599001
# Rtt-ul este: 13647248000si nr ack-ului: 973600501
# Rtt-ul este: 13647248000si nr ack-ului: 973602001
# Rtt-ul este: 13659760000si nr ack-ului: 973603501
# Rtt-ul este: 13659760000si nr ack-ului: 973605001
# Rtt-ul este: 13672272000si nr ack-ului: 973606501
# Rtt-ul este: 13672272000si nr ack-ului: 973608001
# Rtt-ul este: 13684784000si nr ack-ului: 973609501
# Rtt-ul este: 13684784000si nr ack-ului: 973611001
# Rtt-ul este: 13697296000si nr ack-ului: 973612501
# Rtt-ul este: 13697296000si nr ack-ului: 973614001
# Rtt-ul este: 13709808000si nr ack-ului: 973615501
# Rtt-ul este: 13709808000si nr ack-ului: 973617001
# Rtt-ul este: 13722320000si nr ack-ului: 973618501
# Rtt-ul este: 13722320000si nr ack-ului: 973620001
# Rtt-ul este: 13734832000si nr ack-ului: 973621501
# Rtt-ul este: 13734832000si nr ack-ului: 973623001
# Rtt-ul este: 13747344000si nr ack-ului: 973624501
# Rtt-ul este: 13747344000si nr ack-ului: 973626001
# Rtt-ul este: 13759856000si nr ack-ului: 973627501
# Rtt-ul este: 13759856000si nr ack-ului: 973629001
# Rtt-ul este: 13772368000si nr ack-ului: 973630501
# Rtt-ul este: 13772368000si nr ack-ului: 973632001
# Rtt-ul este: 13784880000si nr ack-ului: 973633501
# Rtt-ul este: 13784880000si nr ack-ului: 973635001
# Rtt-ul este: 13797392000si nr ack-ului: 973636501
# Rtt-ul este: 13797392000si nr ack-ului: 973638001
# Rtt-ul este: 13809904000si nr ack-ului: 973639501
# Rtt-ul este: 13809904000si nr ack-ului: 973641001
# Rtt-ul este: 13822416000si nr ack-ului: 973642501
# Rtt-ul este: 13822416000si nr ack-ului: 973644001
# Rtt-ul este: 13834928000si nr ack-ului: 973645501
# Rtt-ul este: 13834928000si nr ack-ului: 973647001
# Rtt-ul este: 13847440000si nr ack-ului: 973648501
# Rtt-ul este: 13847440000si nr ack-ului: 973650001
# Rtt-ul este: 13859952000si nr ack-ului: 973651501
# Rtt-ul este: 13859952000si nr ack-ului: 973653001
# Rtt-ul este: 13872464000si nr ack-ului: 973654501
# Rtt-ul este: 13872464000si nr ack-ului: 973656001
# Rtt-ul este: 13884976000si nr ack-ului: 973657501
# Rtt-ul este: 13884976000si nr ack-ului: 973659001
# Rtt-ul este: 13897488000si nr ack-ului: 973660501
# Rtt-ul este: 13897488000si nr ack-ului: 973662001
# Rtt-ul este: 13910000000si nr ack-ului: 973663501
# Rtt-ul este: 13910000000si nr ack-ului: 973665001
# Rtt-ul este: 13922512000si nr ack-ului: 973666501
# Rtt-ul este: 13922512000si nr ack-ului: 973668001
# Rtt-ul este: 13935024000si nr ack-ului: 973669501
# Rtt-ul este: 13935024000si nr ack-ului: 973671001
# Rtt-ul este: 13947536000si nr ack-ului: 973672501
# Rtt-ul este: 13947536000si nr ack-ului: 973674001
# Rtt-ul este: 13960048000si nr ack-ului: 973675501
# Rtt-ul este: 13960048000si nr ack-ului: 973677001
# Rtt-ul este: 13972560000si nr ack-ului: 973678501
# Rtt-ul este: 13972560000si nr ack-ului: 973680001
# Rtt-ul este: 13985072000si nr ack-ului: 973681501
# Rtt-ul este: 13985072000si nr ack-ului: 973683001
# Rtt-ul este: 13997584000si nr ack-ului: 973684501
# Rtt-ul este: 13997584000si nr ack-ului: 973686001
# Rtt-ul este: 14010096000si nr ack-ului: 973687501
# Rtt-ul este: 14010096000si nr ack-ului: 973689001
# Rtt-ul este: 14022608000si nr ack-ului: 973690501
# Rtt-ul este: 14022608000si nr ack-ului: 973692001
# Rtt-ul este: 14035120000si nr ack-ului: 973693501
# Rtt-ul este: 14035120000si nr ack-ului: 973695001
# Rtt-ul este: 14047632000si nr ack-ului: 973696501
# Rtt-ul este: 14047632000si nr ack-ului: 973698001
# Rtt-ul este: 14060144000si nr ack-ului: 973699501
# Rtt-ul este: 14060144000si nr ack-ului: 973701001
# Rtt-ul este: 14072656000si nr ack-ului: 973702501
# Rtt-ul este: 14072656000si nr ack-ului: 973704001
# Rtt-ul este: 14085168000si nr ack-ului: 973705501
# Rtt-ul este: 14085168000si nr ack-ului: 973707001
# Rtt-ul este: 14097680000si nr ack-ului: 973708501
# Rtt-ul este: 14097680000si nr ack-ului: 973710001
# Rtt-ul este: 14110192000si nr ack-ului: 973711501
# Rtt-ul este: 14110192000si nr ack-ului: 973713001
# Rtt-ul este: 14122704000si nr ack-ului: 973714501
# Rtt-ul este: 14122704000si nr ack-ului: 973716001
# Rtt-ul este: 14135216000si nr ack-ului: 973717501
# Rtt-ul este: 14135216000si nr ack-ului: 973719001
# Rtt-ul este: 14147728000si nr ack-ului: 973720501
# Rtt-ul este: 14147728000si nr ack-ului: 973722001
# Rtt-ul este: 14160240000si nr ack-ului: 973723501
# Rtt-ul este: 14160240000si nr ack-ului: 973725001
# Rtt-ul este: 14172752000si nr ack-ului: 973726501
# Rtt-ul este: 14172752000si nr ack-ului: 973728001
# Rtt-ul este: 14185264000si nr ack-ului: 973729501
# Rtt-ul este: 14185264000si nr ack-ului: 973731001
# Rtt-ul este: 14197776000si nr ack-ului: 973732501
# Rtt-ul este: 14197776000si nr ack-ului: 973734001
# Rtt-ul este: 14210288000si nr ack-ului: 973735501
# Rtt-ul este: 14210288000si nr ack-ului: 973737001
# Rtt-ul este: 14222800000si nr ack-ului: 973738501
# Rtt-ul este: 14222800000si nr ack-ului: 973740001
# Rtt-ul este: 14235312000si nr ack-ului: 973741501
# Rtt-ul este: 14235312000si nr ack-ului: 973743001
# Rtt-ul este: 14247824000si nr ack-ului: 973744501
# Rtt-ul este: 14247824000si nr ack-ului: 973746001
# Rtt-ul este: 14260336000si nr ack-ului: 973747501
# Rtt-ul este: 14260336000si nr ack-ului: 973749001
# Rtt-ul este: 14272848000si nr ack-ului: 973750501
# Rtt-ul este: 14272848000si nr ack-ului: 973752001
# Rtt-ul este: 14285360000si nr ack-ului: 973753501
# Rtt-ul este: 14285360000si nr ack-ului: 973755001
# Rtt-ul este: 14297872000si nr ack-ului: 973756501
# Rtt-ul este: 14297872000si nr ack-ului: 973758001
# Rtt-ul este

# %%
# Deseneaza graficele pentru throughput is cwnd. Figsize poate fi modificat pentru a schimba dimensiunea figurilor.
fig, axs = plt.subplots(ncols=2, figsize=(18, 8))

plot_throughput(axs[0], num_cons)
plot_cwnd(axs[1], num_cons)
plt.show()

# %%
# Deseneaza dimensiunea cozii din router in MSS.
fig, axs = plt.subplots(ncols=2, figsize=(18, 8))

plot_router_queue(axs[0], router_queue_size)
plt.show()

# %% [markdown]
# ## Masurarea performantei pentru clasamentul pe serie
#
# Pentru a face distinctia intre implementari, vom acorda un scor de performanta algoritmului. Scorul este impartit in 3 categorii:
#
# * thrghouput (300p)
# * fairness (300p)
# * latenta (300p)

# %%
# Functii helper folosite pentru a calcula valori precum average thrghouput
import math

# Calcuelaza average-ul dintr-o coloana dintr-un fisier .dat
def avg_col(data_path, col, scale):
        x1 = []
        with open(data_path) as f:
            for line in f:
                values = line.split()
                x1.append(float(values[col]) * scale)
        return sum(x1)/(len(x1))

# Afiseaza throughput-ul pentru o conexiune si traseazao linie orizontala la valoarea ideala.
def plot_throughput2(axs, data_path, bandwidth):
    axs.set_ylabel('Throughput (Mbps)')
    axs.set_xlabel('Time (s)')
    x1 = []
    y1 = []
    with open(data_path) as f:
        for line in f:
            values = line.split()
            x1.append(float(values[0]))
            y1.append(float(values[12]) * 8 / 1000000)
            
    axs.hlines(y=bandwidth, xmin=0, xmax=x1[-1], linewidth=2, color='r')
    # Ca sa arata graficul mai bine, nu luam in considerare primele 4 tick-uri
    axs.plot(x1[4:], y1[4:], '-')
    
# Afiseaza throughput-ul dintr-un anumit folder .dat
def plot_throughput_from_data(axs, num_cons, data_folder):
    axs.set_ylabel('Throughput (Mbps)')
    axs.set_xlabel('Time (s)')
    # Valorile din fisieri sunt in byes asa ca le inmultim cu 8/1000000 ca sa trecem in Mb/s
    plot_generic(axs, 0, 12, 'Throughput', 'Time (s)', 8 / 1000000, num_cons, data_folder)

# %% [markdown]
# ### Throughput (Viteza de transmisie)
# Ne intereseaza sa avem un averge thrghouput = BDP. Asta inseamna ca ar trebui sa ajungem

# %%
# Urmatoarele trei verifica daca algoritmul de congestie foloseste banda intr-un mod optim

# Vom masura rata de transmisie in diferite combinatii de throughput si latency. Coada de pachete din router are dimensiunea BDP-ului.
MSS = 1500 # in bytes
latency = [0.1, 1, 10] # ms
bandwidth = [10, 100, 1000] # Mbs
bdp = [ (i * j * 2 ) for i, j in zip(latency, bandwidth)]
queue_size_in_mss = [ int(i * 1000000 / (1500 * 8)) for i in bdp]
avg = []

# Rulam pentru trei scenarii diferite
for i in range(3):
    data_folder = "tmp/thr{}/".format(i)
    # Creeaza directorul in care vom salva rezultatele simularii
    # !mkdir -p {data_folder}
    ! ./htsim_dumbell_cc -conns 1 -end 20000 -log 100 -q {queue_size_in_mss[i]} \
         -latency {latency[i]} -bandwidth {bandwidth[i]}; ./scripts/parse.sh logout.dat {data_folder}
    avg.append(avg_col("tmp/thr{}/0.dat".format(i), 12, 8 / 1000000))
    print("\n##### [RESULT] Average thrghouput {} vs {} expected".format(avg[i], bandwidth[i]))

# Calculeaza scorul pentru clasament. Acesta este media la cat am reusit sa acoperim din bandwidth in cele 3 scenarii.
score_thrghouput = (avg[0]/bandwidth[0] + avg[1]/ bandwidth[1] + avg[2]/ bandwidth[2]) * 100
print("+++++ Scorul pentru aceasta categorie: {} puncte".format(score_thrghouput))

# Deseneaza graficele thrghouput-ului. Linia orizontala rosie reprezinta valoarea asteptata.
fig, axs = plt.subplots(ncols=3, figsize=(28, 8))
for i in range(3):
    plot_throughput2(axs[i], "tmp/thr{}/0.dat".format(i), bandwidth[i])
plt.show()

# %% [markdown]
# ## Fairness
#
# Vrem ca banda sa fie impartita corect intre mai multe conexiuni.

# %%
# Urmatorul experiment verifica daca algoritmul imparte in mod egal banda intre mai multe conexiuni.
num_cons = [4, 8, 16]
# In MSS
router_queue_size = 800
latency = [5, 2, 10]
fairness = []

# Rulam pentru trei scenarii diferite
for i in range(3):
    data_folder = "tmp/fair{}/".format(i)
    # !mkdir -p {data_folder}
    # Ruleaza experimentul cu num_cons[i] conexiuni.
    ! ./htsim_dumbell_cc -conns {num_cons[i]} -end 80000 -log 100 -q {router_queue_size} -latency {latency[i]} \
    -startdelta 500; ./scripts/parse.sh logout.dat {data_folder}
    
    # Calculeaza raportul dintre throughput-ul cel mai mic al uneia dintre conexiuni cu cel mai mare. Ideal acesta ar trebui sa fie 1 pentru ca bandwidth-ul se imparte egal intre toate conexiunile
    avgs = []
    for j in range(num_cons[i]):
        # 8/10000000 pentru a trece in Mbps
        avgs.append(avg_col("tmp/fair{}/{}.dat".format(i, j), 12, 8 / 1000000))

    fairness.append(min(avgs)/max(avgs))
    print("\n####### Min/Max average thrghouput: {}/{}".format(min(avgs), max(avgs)))

score_fairness = (fairness[0] + fairness[1] + fairness[2]) / 3 * 100 * 3
print("+++++ Scorul pentru aceasta categorie: {} puncte".format(score_fairness))

# Deseneaza thoughput-ul pentru conexiuni. Din figsize putem schimba dimensiunea figurilor.
fig, axs = plt.subplots(ncols=3, figsize=(26, 8))
for i in range(3):
    plot_throughput_from_data(axs[i], 4, "tmp/fair{}/".format(i))
plt.show()

# %% [markdown]
# ## Latenta

# %% [markdown]
# Vom masura latenta in functie de cat de incarcata este coada din router. Astfel, punctajul este acordat in functie de gradul de umplere al cozii.

# %%
# Acest experiment masoara latenta per pachet introdusa de algoritmul de congestion control. Cu cat avem o coada mai mare de pachete ce asteapta la router
# cu atat latenta va creste.

MSS = 1500 # in bytes
latency = [1, 1, 1] # ms
bandwidth = [10, 50, 100] # Mbs
bdp = [ (i * j * 2 ) for i, j in zip(latency, bandwidth)]
# Coada din router o sa aiba 10 BDP
queue_size_in_mss = [ int(i * 1000000 / (MSS * 8)) * 10 for i in bdp]
num_cons = [2, 4, 3]
avgs = []

# Rulam pentru trei scenarii diferite
for i in range(3):
    data_folder = "tmp/lat{}/".format(i)
    # !mkdir -p {data_folder}
    ! ./htsim_dumbell_cc -conns {num_cons[i]} -end 60000 -log 100 -q {queue_size_in_mss[i]} -startdelta 200 \
        -latency {latency[i]} -bandwidth {bandwidth[i]}; ./scripts/parse.sh logout.dat {data_folder}
    # Inmultim coloana 12 (numarul de bytes in buffer-ul routerului) cu1/1500 pentru ca vrem sa masuram in MSS (1500 de bytes)
    avgs.append(avg_col("tmp/lat{}/q.dat".format(i), 12, 1/1500))

score_latency = 300 - (avgs[0] / queue_size_in_mss[0] * 100 + avgs[1] / queue_size_in_mss[1] * 100 + avgs[2] / queue_size_in_mss[2] * 100)
print("\n+++++ Scorul pentru aceasta categorie: {} puncte".format(score_latency))

# Deseneaza numarul de pachete in coada. Linia orizontala reprezinta dimensiunea maxima in MSS a cozii ruterului.
fig, axs = plt.subplots(ncols=3, figsize=(26, 8))
for i in range(3):
    plot_router_queue(axs[i], queue_size_in_mss[i], "tmp/lat{}/".format(i))
plt.show()

# %% [markdown]
# # Evlauarea proiectului
#
# Coordonatorul de echipa va incarca arhiva rezultata in urma rularii `create_archive.sh` pe Moodle. Arhiva va include un fisier `team.secret` cu ID-ul secret pe care
# l-ati pus la inscriere si un writeup in format pdf. Nota finala la proiect va fi calculata la final in functie de pozitia in clasament si rezultatele la cele trei categorii.

# %%
scor_total = score_thrghouput + score_fairness + score_latency
print("Scor total {}/900".format(scor_total))
